# %%
import pandas as pd
import numpy as np
import matplotlib as mplb
import seaborn as sns
import scypy as sp
import sklearn
import matplotlib.pyplot as plt

# %%
test_df = pd.read_csv(
    "test.csv"
)

# %%
train_df = pd.read_csv(
    "train.csv"
)
