# %% [markdown]
# # SQL guide

# %% [markdown]
# ## Opening and closing SQLite in python

# %%
import sqlite3 as sq

con = sq.connect("saper.db")  # opening db
cur = con.cursor()  # creating a cursor
cur.execute("""
""")
con.close()  # closing db


with sq.connect("saper.db") as con: # a safer way to use db
    cur = con.cursor()
    cur.execute("""
    """)

# %% [markdown]
# ### data types in SQLite
# - NULL
# - INTEGER
# - REAL
# - TEXT
# - BLOB

# %% [markdown]
# ### Creating DB

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        CREATE TABLE users (
            name TEXT,
            gender INTEGER,
            age INTEGER,
            score INTEGER
        );
    """)

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        CREATE TABLE IF NOT EXISTS users (
            name TEXT,
            gender INTEGER ,
            age INTEGER,
            score INTEGER
        );
    """)

# %% [markdown]
# ### Deleting DB

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        DROP TABLE users;
    """)

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        DROP TABLE IF EXISTS users;
    """)

# %% [markdown]
# ### Constraints

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        CREATE TABLE IF NOT EXISTS users(
            name TEXT NOT NULL,
            passport INTEGER UNIQUE,
            gender INTEGER DEFAULT 1,
            age INTEGER DEFAULT 18,
            score INTEGER
        );
    """)

# %% [markdown]
# ### Primary key

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        CREATE TABLE IF NOT EXISTS users(
            user_id INTEGER UNIQUE PRIMARY KEY AUTOINCREMENT,
            name TEXT NOT NULL,
            passport INTEGER UNIQUE,
            gender INTEGER DEFAULT 1,
            age INTEGER DEFAULT 18,
            score INTEGER
        );
    """)

# %% [markdown]
# ## INSERT and SELECT

# %% [markdown]
# ### INSERT

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        INSERT INTO users VALUES (1, 'Donald Trump', 12345678, 2, 100, -100);
    """)

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        INSERT INTO users (name, passport, age, score) VALUES ('Barak Obamka', 135444, 200, -1000);
    """)

# %% [markdown]
# ### SELECT

# %% [markdown]
# ### Selecting by columns

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT name, age, score FROM users;
    """)

# %% [markdown]
# ### Selecting all

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT * FROM users;
    """)

# %% [markdown]
# ### Selecting by a condition

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT name, age, score FROM users WHERE score<-200;
    """)

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT name, age, score FROM users WHERE score BETWEEN -100 AND 100;
    """)

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT name, age, score FROM users WHERE score BETWEEN -100 AND 100 AND age > 0 OR gender in (1, 2);
    """)

# %% [markdown]
# ### Selecting and sorting

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT * FROM users ORDER BY age;
    """)
# ascending order by default

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT * FROM users ORDER BY age ASC;
    """)
# descending order manually

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT * FROM users ORDER BY age DESC;
    """)
# descending order

# %% [markdown]
# ### Limit

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT * FROM users LIMIT 1;
    """)
# only 1 row will be given

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT * FROM users LIMIT 1 OFFSET 2;
    """)
# skipping 2 first rows

# %% [markdown]
# ### Outputting into python

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT * FROM users WHERE age > 2;
    """)
    result = cur.fetchall()
    first = cur.fetchone()
    three_first = cur.fetchmany(2)
    print(result)
    print(first)
    print(three_first)
# Out:
# [(1, 'Donald Trump', 12345678, 2, 100, -100), (2, 'Barak Obamka', 123456, 1, 200, -1000)]
# None
# []

# %% [markdown]
# ## UPDATE and DELETE

# %% [markdown]
# ### UPDATE

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        UPDATE users SET score = 777;
    """)
# changes all rows

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        UPDATE users SET score = 777 WHERE user_id < 3;
    """)
# changes first 2 rows

# %% [markdown]
# ### DELETE

# %%
with sq.connect("saper.db") as con:
    cur = con.cursor()
    cur.execute("""
        DELETE users WHERE score > 0;
    """)
# deletes rows with score > 0

# %% [markdown]
# ## GROUP BY

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT 
            COUNT(*) AS group, 
            SUM(score) AS total,
            AVG(score) AS average, 
            MIN(score) AS minimum_value,
            MAX(score) AS maximum_value
        FROM user
        WHERE score > 0
        GROUP BY gender
        HAVING tatal > 0
        ORDER BY total DESC;
    """)

# %% [markdown]
# ## JOIN

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        CREATE TABLE IF NOT EXISTS games(
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            user_id INTEGER NOT NULL,
            score INTEGER DEFAULT 0,
            time INTEGER DEFAULT 0,
            FOREIGN KEY (user_id) REFERENCES user(id) ON DELETE CASCADE
        );
    """)
# creating a games table

# %%
import random
with sq.connect("generated.db") as con:
    cur = con.cursor()
    for i in range(1000):
        user_id = random.randint(100, 1000)
        score = random.randint(-1000, 1000)
        time = random.randint(-1000, 1000)
        cur.execute(f"""
            INSERT INTO games (user_id, score, time) VALUES ({user_id}, {score}, {time});
        """)
# filling the games table

# %%
import random
with sq.connect("generated.db") as con:
    cur = con.cursor()
    for i in range(1000):
        passport = random.randint(100, 1000)
        age = random.randint(0, 1000)
        score = random.randint(-1000, 1000)
        cur.execute(f"""
            INSERT INTO user (username, email, passport, age, score) VALUES ('Some Guy', "someone@gmail.com", {passport}, {age}, {score});
        """)
# filling the users table

# %% [markdown]
# ### Inner JOIN

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT username, email, gender, games.score, games.time FROM games
        JOIN user ON games.user_id = user.id;
    """)
"""
    We are joining a table user to the table games. We use an INNER JOIN, only the results with all the fields present will be shown
"""

# %% [markdown]
# ### LEFT JOIN

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT games.id AS game_id, username, email, gender, games.score, games.time 
        FROM games
        LEFT JOIN user ON games.user_id = user.id;
    """)

"""
    We are joining a table user to the table games. We use a left join, so the games with no corresponding isers will be left with null value
"""

# %% [markdown]
# ### RIGHT JOIN

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT games.id AS game_id, username, email, gender, games.score, games.time 
        FROM games
        RIGHT JOIN user ON games.user_id = user.id;
    """)

"""
    We are joining a table user to the table games. We use a RIGHT JOIN, 
    so all the users will be taken, and if the have no games the field from game table will be taken as nulls
"""

# %% [markdown]
# ### FULL JOIN

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT games.id AS game_id, username, email, gender, games.score, games.time 
        FROM games
        FULL JOIN user ON games.user_id = user.id;
    """)

"""
    We are joining a table user to the table games. We use a FULL JOIN, 
    so both the users and games will be taken, 
    empty fields will be filled with nulls
"""

# %% [markdown]
# ## UNION

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT val1, type1 FROM table1
        UNION
        SELECT val2, type2 FROM table2
    """)

"""
    Union leaves only unique rows
"""

# %% [markdown]
# ## execute, executemany, executescript, commit, rollback, lastrowid

# %% [markdown]
# ### commit and close

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("""
        SELECT val1, type1 FROM table1
        UNION
        SELECT val2, type2 FROM table2
    """)
    # con.commit() run automatically afrer closing
    # con.close()

# %% [markdown]
# ### execute()

# %%
data = {
    "model": "BMW",
    "price": 7000000
}
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.execute("INSERT INTO cars (:model, :price) VALUES(?, ?)", data)
    # named parameter are marked with a colon before them

# %% [markdown]
# ### executemany()

# %%
cars = [
    ("BMW", 730000),
    ("Mercedez", 324344),
]

with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.executemany("INSERT INTO cars (model, price) VALUES(?, ?)", cars)
    # will be executed for all tupples in a list
    # parameters are marked with a ?

# %% [markdown]
# ### executescript()

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.executescript(
        """
            INSERT INTO cars (model, price) VALUES('BMW', 70000000);
            SELECT * FROM cars;
        """
        )
    # will be executed for all tupples in a list
    # parameters are marked with a ?

# %% [markdown]
# ### commit and rollback

# %%
con = None
try:
    con = sq.connect("cars.db")
    cur = con.cursor()

    cur.executescript("""CREATE TABLE IF NOT EXISTS cars (
            car_id INTEGER PRIMARY KEY AUTOINCREMENT,
            model TEXT,
            price INTEGER
        );
        BEGIN;
        INSERT INTO cars VALUES(NULL,'Audi',52642);
        INSERT INTO cars VALUES(NULL,'Mercedes',57127);
        INSERT INTO cars VALUES(NULL,'Skoda',9000);
        INSERT INTO cars VALUES(NULL,'Volvo',29000);
        INSERT INTO cars VALUES(NULL,'Bentley',350000);
        UPDATE cars SET price = price+1000
    """)
    con.commit()

except sq.Error as e:
    if con: con.rollback()
    print("Ошибка выполнения запроса")
finally:
    if con: con.close()

# %% [markdown]
# ## fetchall, fetchmany, fetchone, Binary, iterdump

# %% [markdown]
# ### fetchone

# %%
cars = [
    ('Audi', 52642),
    ('Mercedes', 57127),
    ('Skoda', 9000),
    ('Volvo', 29000),
    ('Bentley', 350000)
]

with sq.connect("generated.db") as con:
    cur = con.cursor()
    cur.executescript(
    """
        CREATE TABLE IF NOT EXISTS car(
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT NOT NULL,
            price INTEGER DEFAULT 0
        );
    """)

    cur.executemany("INSERT INTO car(name, price) VALUES (?, ?)", cars)

    cur.execute("SELECT name, price FROM car")

    rows = cur.fetchone()
    print(rows)
# Out:
# ('Audi', 52642)

# %% [markdown]
# ### fetchall

# %%
cars = [
    ('Audi', 52642),
    ('Mercedes', 57127),
    ('Skoda', 9000),
    ('Volvo', 29000),
    ('Bentley', 350000)
]

with sq.connect("generated.db") as con:
    cur = con.cursor()

    cur.execute("SELECT name, price FROM car")

    rows = cur.fetchall()
    print(rows)
# Out:
# [('Audi', 52642), ('Mercedes', 57127), ('Skoda', 9000), ('Volvo', 29000), ('Bentley', 350000), ('Audi', 52642), ('Mercedes', 57127), ('Skoda', 9000), ('Volvo', 29000), ('Bentley', 350000)]

# %% [markdown]
# ### fetchmany

# %%
cars = [
    ('Audi', 52642),
    ('Mercedes', 57127),
    ('Skoda', 9000),
    ('Volvo', 29000),
    ('Bentley', 350000)
]

with sq.connect("generated.db") as con:
    cur = con.cursor()

    cur.execute("SELECT name, price FROM car")

    rows = cur.fetchmany()
    print(rows)
# Out:
# [('Audi', 52642), ('Mercedes', 57127), ('Skoda', 9000)]

# %% [markdown]
# ### Row factory

# %%
cars = [
    ('Audi', 52642),
    ('Mercedes', 57127),
    ('Skoda', 9000),
    ('Volvo', 29000),
    ('Bentley', 350000)
]

with sq.connect("generated.db") as con:
    con.row_factory = sq.Row
    cur = con.cursor()

    cur.execute("SELECT name, price FROM car")

    rows = cur.fetchall()
    for result in cur:
        print(result['name'], result["price"])

# %% [markdown]
# ## Binary files

# %%
cur.executescript("""CREATE TABLE IF NOT EXISTS users (
    name TEXT,
    ava BLOB,
    score INTEGER)
""")

def readAva(n):
    try:
        with open(f"avas/{n}.png", "rb") as f:
            return f.read()
    except IOError as e:
        print(e)
        return False

img = readAva(1)
if img:
    binary = sq.Binary(img)
    cur.execute("INSERT INTO users VALUES ('Николай', ?, 1000)", (binary,))

# %% [markdown]
# ## Backuping DB with iterdump()

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    for sql in con.iterdump():
        print(sql)
    with open("sql_damp.sql", "w") as f:
        for sql in con.iterdump():
            f.write(sql)
# Out:
# BEGIN TRANSACTION;
# CREATE TABLE car(
#             id INTEGER PRIMARY KEY AUTOINCREMENT,
#             name TEXT NOT NULL,
#             price INTEGER DEFAULT 0
#         );
# INSERT INTO "car" VALUES(1,'Audi',52642);
# INSERT INTO "car" VALUES(2,'Mercedes',57127);
# INSERT INTO "car" VALUES(3,'Skoda',9000);
# INSERT INTO "car" VALUES(4,'Volvo',29000);
# INSERT INTO "car" VALUES(5,'Bentley',350000);
# INSERT INTO "car" VALUES(6,'Audi',52642);
# INSERT INTO "car" VALUES(7,'Mercedes',57127);
# INSERT INTO "car" VALUES(8,'Skoda',9000);
# INSERT INTO "car" VALUES(9,'Volvo',29000);
# INSERT INTO "car" VALUES(10,'Bentley',350000);
# CREATE TABLE games(
#             id INTEGER PRIMARY KEY AUTOINCREMENT,
#             user_id INTEGER NOT NULL,
#             score INTEGER DEFAULT 0,
#             time INTEGER DEFAULT 0,
#             FOREIGN KEY (user_id) REFERENCES user(id) ON DELETE CASCADE
#         );
# INSERT INTO "games" VALUES(1,60,-83,-352);
# INSERT INTO "games" VALUES(2,45,383,761);
# INSERT INTO "games" VALUES(3,41,782,-100);
# INSERT INTO "games" VALUES(4,79,-478,383);
# INSERT INTO "games" VALUES(5,32,-731,-610);
# INSERT INTO "games" VALUES(6,58,-123,-106);
# INSERT INTO "games" VALUES(7,8,995,935);
# INSERT INTO "games" VALUES(8,87,948,741);
# INSERT INTO "games" VALUES(9,40,-81,-61);
# INSERT INTO "games" VALUES(10,75,162,611);
# INSERT INTO "games" VALUES(11,48,636,473);
# INSERT INTO "games" VALUES(12,56,-628,-100);
# INSERT INTO "games" VALUES(13,0,-840,779);
# INSERT INTO "games" VALUES(14,63,557,-520);
# INSERT INTO "games" VALUES(15,28,773,106);
# INSERT INTO "games" VALUES(16,31,55,535);
# INSERT INTO "games" VALUES(17,80,331,-464);
# INSERT INTO "games" VALUES(18,19,877,-826);
# INSERT INTO "games" VALUES(19,6,305,435);
# INSERT INTO "games" VALUES(20,34,-808,481);
# INSERT INTO "games" VALUES(21,32,335,58);
# INSERT INTO "games" VALUES(22,92,-754,-644);
# INSERT INTO "games" VALUES(23,79,86,-559);
# INSERT INTO "games" VALUES(24,74,815,718);
# INSERT INTO "games" VALUES(25,57,-446,-551);
# INSERT INTO "games" VALUES(26,66,446,-389);
# INSERT INTO "games" VALUES(27,51,-78,247);
# INSERT INTO "games" VALUES(28,93,565,176);
# INSERT INTO "games" VALUES(29,81,578,-127);
# INSERT INTO "games" VALUES(30,7,-27,127);
# INSERT INTO "games" VALUES(31,53,-384,451);
# INSERT INTO "games" VALUES(32,98,349,3);
# INSERT INTO "games" VALUES(33,43,96,916);
# INSERT INTO "games" VALUES(34,3,-324,430);
# INSERT INTO "games" VALUES(35,7,-843,-443);
# INSERT INTO "games" VALUES(36,64,-987,362);
# INSERT INTO "games" VALUES(37,42,992,-633);
# INSERT INTO "games" VALUES(38,7,972,828);
# INSERT INTO "games" VALUES(39,91,756,484);
# INSERT INTO "games" VALUES(40,4,204,833);
# INSERT INTO "games" VALUES(41,89,191,38);
# INSERT INTO "games" VALUES(42,75,673,-343);
# INSERT INTO "games" VALUES(43,65,-910,-100);
# INSERT INTO "games" VALUES(44,84,143,648);
# INSERT INTO "games" VALUES(45,49,96,180);
# INSERT INTO "games" VALUES(46,94,-993,-501);
# INSERT INTO "games" VALUES(47,27,-484,-706);
# INSERT INTO "games" VALUES(48,30,226,58);
# INSERT INTO "games" VALUES(49,47,630,709);
# INSERT INTO "games" VALUES(50,90,-632,647);
# INSERT INTO "games" VALUES(51,97,-540,24);
# INSERT INTO "games" VALUES(52,13,36,322);
# INSERT INTO "games" VALUES(53,78,167,239);
# INSERT INTO "games" VALUES(54,1,-147,236);
# INSERT INTO "games" VALUES(55,58,932,-355);
# INSERT INTO "games" VALUES(56,25,216,-808);
# INSERT INTO "games" VALUES(57,17,323,140);
# INSERT INTO "games" VALUES(58,25,10,904);
# INSERT INTO "games" VALUES(59,79,-178,505);
# INSERT INTO "games" VALUES(60,63,721,506);
# INSERT INTO "games" VALUES(61,41,584,880);
# INSERT INTO "games" VALUES(62,48,958,442);
# INSERT INTO "games" VALUES(63,36,-403,562);
# INSERT INTO "games" VALUES(64,13,-86,-585);
# INSERT INTO "games" VALUES(65,85,93,728);
# INSERT INTO "games" VALUES(66,67,438,-19);
# INSERT INTO "games" VALUES(67,83,-572,-337);
# INSERT INTO "games" VALUES(68,35,-840,-999);
# INSERT INTO "games" VALUES(69,3,-227,995);
# INSERT INTO "games" VALUES(70,8,370,-545);
# INSERT INTO "games" VALUES(71,1,-562,944);
# INSERT INTO "games" VALUES(72,49,-270,688);
# INSERT INTO "games" VALUES(73,1,101,172);
# INSERT INTO "games" VALUES(74,30,-68,-937);
# INSERT INTO "games" VALUES(75,69,759,-391);
# INSERT INTO "games" VALUES(76,42,-204,-479);
# INSERT INTO "games" VALUES(77,53,145,671);
# INSERT INTO "games" VALUES(78,24,-195,-752);
# INSERT INTO "games" VALUES(79,7,-570,-523);
# INSERT INTO "games" VALUES(80,92,-210,424);
# INSERT INTO "games" VALUES(81,91,981,-890);
# INSERT INTO "games" VALUES(82,82,-985,752);
# INSERT INTO "games" VALUES(83,59,541,-60);
# INSERT INTO "games" VALUES(84,37,654,-496);
# INSERT INTO "games" VALUES(85,72,168,-768);
# INSERT INTO "games" VALUES(86,19,-588,-777);
# INSERT INTO "games" VALUES(87,21,-739,-482);
# INSERT INTO "games" VALUES(88,33,-883,565);
# INSERT INTO "games" VALUES(89,47,-122,129);
# INSERT INTO "games" VALUES(90,14,-1000,549);
# INSERT INTO "games" VALUES(91,49,-274,-135);
# INSERT INTO "games" VALUES(92,45,27,547);
# INSERT INTO "games" VALUES(93,6,-37,-680);
# INSERT INTO "games" VALUES(94,91,-434,79);
# INSERT INTO "games" VALUES(95,72,487,-201);
# INSERT INTO "games" VALUES(96,74,-654,346);
# INSERT INTO "games" VALUES(97,25,116,877);
# INSERT INTO "games" VALUES(98,71,25,-308);
# INSERT INTO "games" VALUES(99,100,714,-311);
# INSERT INTO "games" VALUES(100,84,297,-766);
# INSERT INTO "games" VALUES(101,69,-187,-390);
# INSERT INTO "games" VALUES(102,81,575,-336);
# INSERT INTO "games" VALUES(103,46,-276,939);
# INSERT INTO "games" VALUES(104,21,231,-441);
# INSERT INTO "games" VALUES(105,94,-629,23);
# INSERT INTO "games" VALUES(106,60,-312,-440);
# INSERT INTO "games" VALUES(107,19,-811,-388);
# INSERT INTO "games" VALUES(108,87,-171,-757);
# INSERT INTO "games" VALUES(109,76,526,972);
# INSERT INTO "games" VALUES(110,13,-879,-777);
# INSERT INTO "games" VALUES(111,11,-442,254);
# INSERT INTO "games" VALUES(112,59,876,51);
# INSERT INTO "games" VALUES(113,83,-496,142);
# INSERT INTO "games" VALUES(114,27,634,628);
# INSERT INTO "games" VALUES(115,37,-267,-753);
# INSERT INTO "games" VALUES(116,23,765,-817);
# INSERT INTO "games" VALUES(117,80,-742,746);
# INSERT INTO "games" VALUES(118,76,-291,-615);
# INSERT INTO "games" VALUES(119,84,244,992);
# INSERT INTO "games" VALUES(120,12,196,325);
# INSERT INTO "games" VALUES(121,61,118,789);
# INSERT INTO "games" VALUES(122,45,-515,-9);
# INSERT INTO "games" VALUES(123,50,-555,-860);
# INSERT INTO "games" VALUES(124,78,598,305);
# INSERT INTO "games" VALUES(125,12,-231,825);
# INSERT INTO "games" VALUES(126,95,31,545);
# INSERT INTO "games" VALUES(127,10,382,-453);
# INSERT INTO "games" VALUES(128,91,979,650);
# INSERT INTO "games" VALUES(129,38,-677,185);
# INSERT INTO "games" VALUES(130,28,903,-965);
# INSERT INTO "games" VALUES(131,57,599,134);
# INSERT INTO "games" VALUES(132,72,-676,-93);
# INSERT INTO "games" VALUES(133,85,-619,210);
# INSERT INTO "games" VALUES(134,98,-833,-474);
# INSERT INTO "games" VALUES(135,26,-402,988);
# INSERT INTO "games" VALUES(136,34,519,706);
# INSERT INTO "games" VALUES(137,98,551,-204);
# INSERT INTO "games" VALUES(138,18,212,338);
# INSERT INTO "games" VALUES(139,97,-534,-674);
# INSERT INTO "games" VALUES(140,26,-141,-654);
# INSERT INTO "games" VALUES(141,6,618,-445);
# INSERT INTO "games" VALUES(142,59,38,-620);
# INSERT INTO "games" VALUES(143,75,-455,-99);
# INSERT INTO "games" VALUES(144,77,-585,335);
# INSERT INTO "games" VALUES(145,91,449,596);
# INSERT INTO "games" VALUES(146,1,925,822);
# INSERT INTO "games" VALUES(147,36,-740,-116);
# INSERT INTO "games" VALUES(148,91,369,145);
# INSERT INTO "games" VALUES(149,59,493,-380);
# INSERT INTO "games" VALUES(150,3,-840,479);
# INSERT INTO "games" VALUES(151,73,-619,-34);
# INSERT INTO "games" VALUES(152,29,781,231);
# INSERT INTO "games" VALUES(153,56,170,-647);
# INSERT INTO "games" VALUES(154,57,-905,-828);
# INSERT INTO "games" VALUES(155,67,-473,885);
# INSERT INTO "games" VALUES(156,40,821,-337);
# INSERT INTO "games" VALUES(157,34,-130,-705);
# INSERT INTO "games" VALUES(158,35,-47,201);
# INSERT INTO "games" VALUES(159,64,-633,-506);
# INSERT INTO "games" VALUES(160,97,-467,9);
# INSERT INTO "games" VALUES(161,72,-750,-358);
# INSERT INTO "games" VALUES(162,73,308,746);
# INSERT INTO "games" VALUES(163,62,946,282);
# INSERT INTO "games" VALUES(164,86,73,918);
# INSERT INTO "games" VALUES(165,55,-671,-603);
# INSERT INTO "games" VALUES(166,28,-470,-700);
# INSERT INTO "games" VALUES(167,96,-183,989);
# INSERT INTO "games" VALUES(168,39,432,-94);
# INSERT INTO "games" VALUES(169,61,-748,569);
# INSERT INTO "games" VALUES(170,60,-794,-830);
# INSERT INTO "games" VALUES(171,52,334,-550);
# INSERT INTO "games" VALUES(172,26,51,-855);
# INSERT INTO "games" VALUES(173,54,349,901);
# INSERT INTO "games" VALUES(174,60,127,-372);
# INSERT INTO "games" VALUES(175,72,745,499);
# INSERT INTO "games" VALUES(176,4,599,-793);
# INSERT INTO "games" VALUES(177,6,-771,-355);
# INSERT INTO "games" VALUES(178,73,861,7);
# INSERT INTO "games" VALUES(179,16,385,145);
# INSERT INTO "games" VALUES(180,27,605,-105);
# INSERT INTO "games" VALUES(181,6,-981,36);
# INSERT INTO "games" VALUES(182,47,-716,-463);
# INSERT INTO "games" VALUES(183,98,826,-193);
# INSERT INTO "games" VALUES(184,68,-696,567);
# INSERT INTO "games" VALUES(185,78,308,789);
# INSERT INTO "games" VALUES(186,76,-760,947);
# INSERT INTO "games" VALUES(187,24,-771,-156);
# INSERT INTO "games" VALUES(188,92,84,889);
# INSERT INTO "games" VALUES(189,26,145,-263);
# INSERT INTO "games" VALUES(190,87,903,928);
# INSERT INTO "games" VALUES(191,8,123,803);
# INSERT INTO "games" VALUES(192,48,373,-236);
# INSERT INTO "games" VALUES(193,68,-713,3);
# INSERT INTO "games" VALUES(194,43,-537,-400);
# INSERT INTO "games" VALUES(195,12,-890,-575);
# INSERT INTO "games" VALUES(196,98,-851,-398);
# INSERT INTO "games" VALUES(197,20,-181,-509);
# INSERT INTO "games" VALUES(198,35,-988,909);
# INSERT INTO "games" VALUES(199,3,-870,-775);
# INSERT INTO "games" VALUES(200,41,-130,-555);
# INSERT INTO "games" VALUES(201,43,-899,-929);
# INSERT INTO "games" VALUES(202,98,-707,-96);
# INSERT INTO "games" VALUES(203,10,-768,253);
# INSERT INTO "games" VALUES(204,59,338,-543);
# INSERT INTO "games" VALUES(205,61,-236,431);
# INSERT INTO "games" VALUES(206,28,-342,347);
# INSERT INTO "games" VALUES(207,14,-487,787);
# INSERT INTO "games" VALUES(208,84,528,-778);
# INSERT INTO "games" VALUES(209,3,150,616);
# INSERT INTO "games" VALUES(210,55,424,-650);
# INSERT INTO "games" VALUES(211,25,-596,-358);
# INSERT INTO "games" VALUES(212,46,-747,-513);
# INSERT INTO "games" VALUES(213,45,-421,-801);
# INSERT INTO "games" VALUES(214,10,254,-598);
# INSERT INTO "games" VALUES(215,44,-547,-767);
# INSERT INTO "games" VALUES(216,87,737,-245);
# INSERT INTO "games" VALUES(217,38,867,752);
# INSERT INTO "games" VALUES(218,99,417,-110);
# INSERT INTO "games" VALUES(219,27,-480,-537);
# INSERT INTO "games" VALUES(220,90,178,574);
# INSERT INTO "games" VALUES(221,84,52,687);
# INSERT INTO "games" VALUES(222,84,286,-690);
# INSERT INTO "games" VALUES(223,7,856,131);
# INSERT INTO "games" VALUES(224,89,388,-623);
# INSERT INTO "games" VALUES(225,10,454,620);
# INSERT INTO "games" VALUES(226,72,-928,971);
# INSERT INTO "games" VALUES(227,1,-476,927);
# INSERT INTO "games" VALUES(228,22,-808,960);
# INSERT INTO "games" VALUES(229,22,858,728);
# INSERT INTO "games" VALUES(230,26,-14,945);
# INSERT INTO "games" VALUES(231,60,289,145);
# INSERT INTO "games" VALUES(232,36,-723,718);
# INSERT INTO "games" VALUES(233,86,-252,-29);
# INSERT INTO "games" VALUES(234,50,807,-93);
# INSERT INTO "games" VALUES(235,13,-180,-404);
# INSERT INTO "games" VALUES(236,59,-490,-660);
# INSERT INTO "games" VALUES(237,46,-776,-862);
# INSERT INTO "games" VALUES(238,81,-764,-69);
# INSERT INTO "games" VALUES(239,78,-648,703);
# INSERT INTO "games" VALUES(240,60,-170,-447);
# INSERT INTO "games" VALUES(241,60,-846,816);
# INSERT INTO "games" VALUES(242,5,-338,-282);
# INSERT INTO "games" VALUES(243,65,956,-777);
# INSERT INTO "games" VALUES(244,77,540,119);
# INSERT INTO "games" VALUES(245,49,-650,482);
# INSERT INTO "games" VALUES(246,68,889,424);
# INSERT INTO "games" VALUES(247,66,249,-617);
# INSERT INTO "games" VALUES(248,30,-782,-81);
# INSERT INTO "games" VALUES(249,78,726,281);
# INSERT INTO "games" VALUES(250,98,-520,-379);
# INSERT INTO "games" VALUES(251,58,-4,-510);
# INSERT INTO "games" VALUES(252,79,74,-393);
# INSERT INTO "games" VALUES(253,83,694,567);
# INSERT INTO "games" VALUES(254,66,-7,-177);
# INSERT INTO "games" VALUES(255,38,-235,714);
# INSERT INTO "games" VALUES(256,67,-761,136);
# INSERT INTO "games" VALUES(257,2,-267,581);
# INSERT INTO "games" VALUES(258,30,-671,399);
# INSERT INTO "games" VALUES(259,99,-692,756);
# INSERT INTO "games" VALUES(260,51,786,-657);
# INSERT INTO "games" VALUES(261,67,-502,-326);
# INSERT INTO "games" VALUES(262,94,-759,82);
# INSERT INTO "games" VALUES(263,8,114,847);
# INSERT INTO "games" VALUES(264,29,-132,341);
# INSERT INTO "games" VALUES(265,66,668,239);
# INSERT INTO "games" VALUES(266,92,330,688);
# INSERT INTO "games" VALUES(267,56,850,367);
# INSERT INTO "games" VALUES(268,45,47,895);
# INSERT INTO "games" VALUES(269,45,-386,-282);
# INSERT INTO "games" VALUES(270,73,1,-415);
# INSERT INTO "games" VALUES(271,50,-120,580);
# INSERT INTO "games" VALUES(272,99,-512,-286);
# INSERT INTO "games" VALUES(273,35,485,-962);
# INSERT INTO "games" VALUES(274,56,153,604);
# INSERT INTO "games" VALUES(275,32,692,385);
# INSERT INTO "games" VALUES(276,23,-518,788);
# INSERT INTO "games" VALUES(277,63,-40,396);
# INSERT INTO "games" VALUES(278,19,-420,-585);
# INSERT INTO "games" VALUES(279,84,-532,-250);
# INSERT INTO "games" VALUES(280,84,-535,-277);
# INSERT INTO "games" VALUES(281,95,241,17);
# INSERT INTO "games" VALUES(282,16,630,47);
# INSERT INTO "games" VALUES(283,45,-34,5);
# INSERT INTO "games" VALUES(284,81,-284,576);
# INSERT INTO "games" VALUES(285,37,-957,-438);
# INSERT INTO "games" VALUES(286,31,977,660);
# INSERT INTO "games" VALUES(287,87,-582,255);
# INSERT INTO "games" VALUES(288,71,-636,-163);
# INSERT INTO "games" VALUES(289,13,372,-133);
# INSERT INTO "games" VALUES(290,65,-194,566);
# INSERT INTO "games" VALUES(291,1,-38,-879);
# INSERT INTO "games" VALUES(292,54,851,272);
# INSERT INTO "games" VALUES(293,7,97,654);
# INSERT INTO "games" VALUES(294,86,827,-330);
# INSERT INTO "games" VALUES(295,59,395,573);
# INSERT INTO "games" VALUES(296,53,140,-368);
# INSERT INTO "games" VALUES(297,10,392,214);
# INSERT INTO "games" VALUES(298,18,918,686);
# INSERT INTO "games" VALUES(299,68,-8,-169);
# INSERT INTO "games" VALUES(300,33,-800,707);
# INSERT INTO "games" VALUES(301,65,-140,626);
# INSERT INTO "games" VALUES(302,59,682,384);
# INSERT INTO "games" VALUES(303,65,-824,-564);
# INSERT INTO "games" VALUES(304,90,-300,-23);
# INSERT INTO "games" VALUES(305,22,184,-876);
# INSERT INTO "games" VALUES(306,14,-754,627);
# INSERT INTO "games" VALUES(307,77,792,906);
# INSERT INTO "games" VALUES(308,94,-858,879);
# INSERT INTO "games" VALUES(309,82,597,861);
# INSERT INTO "games" VALUES(310,54,-714,933);
# INSERT INTO "games" VALUES(311,12,-803,532);
# INSERT INTO "games" VALUES(312,80,-790,751);
# INSERT INTO "games" VALUES(313,85,972,-943);
# INSERT INTO "games" VALUES(314,31,271,979);
# INSERT INTO "games" VALUES(315,60,-401,611);
# INSERT INTO "games" VALUES(316,38,-772,-135);
# INSERT INTO "games" VALUES(317,75,-257,955);
# INSERT INTO "games" VALUES(318,100,101,500);
# INSERT INTO "games" VALUES(319,43,-227,-579);
# INSERT INTO "games" VALUES(320,88,-458,160);
# INSERT INTO "games" VALUES(321,77,212,756);
# INSERT INTO "games" VALUES(322,53,984,959);
# INSERT INTO "games" VALUES(323,99,-557,595);
# INSERT INTO "games" VALUES(324,31,-561,811);
# INSERT INTO "games" VALUES(325,25,-830,-957);
# INSERT INTO "games" VALUES(326,5,-548,-477);
# INSERT INTO "games" VALUES(327,50,807,154);
# INSERT INTO "games" VALUES(328,82,195,926);
# INSERT INTO "games" VALUES(329,91,379,-842);
# INSERT INTO "games" VALUES(330,18,-326,754);
# INSERT INTO "games" VALUES(331,41,207,-907);
# INSERT INTO "games" VALUES(332,38,-321,-867);
# INSERT INTO "games" VALUES(333,37,941,422);
# INSERT INTO "games" VALUES(334,42,271,191);
# INSERT INTO "games" VALUES(335,2,-890,-160);
# INSERT INTO "games" VALUES(336,40,176,470);
# INSERT INTO "games" VALUES(337,77,-172,-34);
# INSERT INTO "games" VALUES(338,16,766,-196);
# INSERT INTO "games" VALUES(339,82,615,700);
# INSERT INTO "games" VALUES(340,12,-138,-816);
# INSERT INTO "games" VALUES(341,23,553,-62);
# INSERT INTO "games" VALUES(342,10,-91,499);
# INSERT INTO "games" VALUES(343,52,684,100);
# INSERT INTO "games" VALUES(344,54,935,479);
# INSERT INTO "games" VALUES(345,58,613,-862);
# INSERT INTO "games" VALUES(346,100,-403,-900);
# INSERT INTO "games" VALUES(347,99,-470,-669);
# INSERT INTO "games" VALUES(348,1,-614,-689);
# INSERT INTO "games" VALUES(349,34,-537,-752);
# INSERT INTO "games" VALUES(350,88,-804,418);
# INSERT INTO "games" VALUES(351,70,321,-484);
# INSERT INTO "games" VALUES(352,80,-275,773);
# INSERT INTO "games" VALUES(353,15,-539,-308);
# INSERT INTO "games" VALUES(354,63,-137,781);
# INSERT INTO "games" VALUES(355,74,105,-497);
# INSERT INTO "games" VALUES(356,38,-93,-501);
# INSERT INTO "games" VALUES(357,72,340,-435);
# INSERT INTO "games" VALUES(358,82,-590,623);
# INSERT INTO "games" VALUES(359,90,-816,677);
# INSERT INTO "games" VALUES(360,42,-362,213);
# INSERT INTO "games" VALUES(361,18,480,795);
# INSERT INTO "games" VALUES(362,68,21,-614);
# INSERT INTO "games" VALUES(363,69,-547,-502);
# INSERT INTO "games" VALUES(364,92,-786,963);
# INSERT INTO "games" VALUES(365,65,-194,373);
# INSERT INTO "games" VALUES(366,5,492,-996);
# INSERT INTO "games" VALUES(367,14,185,-673);
# INSERT INTO "games" VALUES(368,10,829,278);
# INSERT INTO "games" VALUES(369,94,491,31);
# INSERT INTO "games" VALUES(370,37,-953,-393);
# INSERT INTO "games" VALUES(371,44,-264,153);
# INSERT INTO "games" VALUES(372,0,-661,489);
# INSERT INTO "games" VALUES(373,46,910,-131);
# INSERT INTO "games" VALUES(374,67,-382,-119);
# INSERT INTO "games" VALUES(375,22,-960,175);
# INSERT INTO "games" VALUES(376,8,-179,67);
# INSERT INTO "games" VALUES(377,55,-270,-993);
# INSERT INTO "games" VALUES(378,44,944,852);
# INSERT INTO "games" VALUES(379,9,-187,238);
# INSERT INTO "games" VALUES(380,98,-839,-786);
# INSERT INTO "games" VALUES(381,89,721,198);
# INSERT INTO "games" VALUES(382,52,149,-735);
# INSERT INTO "games" VALUES(383,5,521,315);
# INSERT INTO "games" VALUES(384,33,298,864);
# INSERT INTO "games" VALUES(385,63,514,-945);
# INSERT INTO "games" VALUES(386,100,-128,-666);
# INSERT INTO "games" VALUES(387,75,505,-949);
# INSERT INTO "games" VALUES(388,60,954,713);
# INSERT INTO "games" VALUES(389,27,480,60);
# INSERT INTO "games" VALUES(390,31,-605,159);
# INSERT INTO "games" VALUES(391,74,-126,362);
# INSERT INTO "games" VALUES(392,60,49,-70);
# INSERT INTO "games" VALUES(393,74,933,965);
# INSERT INTO "games" VALUES(394,97,-826,-78);
# INSERT INTO "games" VALUES(395,8,-326,814);
# INSERT INTO "games" VALUES(396,39,-749,-13);
# INSERT INTO "games" VALUES(397,91,89,280);
# INSERT INTO "games" VALUES(398,75,-975,111);
# INSERT INTO "games" VALUES(399,39,-442,601);
# INSERT INTO "games" VALUES(400,40,-352,317);
# INSERT INTO "games" VALUES(401,56,-314,268);
# INSERT INTO "games" VALUES(402,13,416,595);
# INSERT INTO "games" VALUES(403,70,-652,618);
# INSERT INTO "games" VALUES(404,21,-823,9);
# INSERT INTO "games" VALUES(405,37,-936,46);
# INSERT INTO "games" VALUES(406,85,-518,961);
# INSERT INTO "games" VALUES(407,47,-813,-80);
# INSERT INTO "games" VALUES(408,33,-52,-466);
# INSERT INTO "games" VALUES(409,33,-427,230);
# INSERT INTO "games" VALUES(410,75,700,-880);
# INSERT INTO "games" VALUES(411,61,807,410);
# INSERT INTO "games" VALUES(412,59,-765,246);
# INSERT INTO "games" VALUES(413,19,-56,-564);
# INSERT INTO "games" VALUES(414,30,-114,-395);
# INSERT INTO "games" VALUES(415,30,-507,-709);
# INSERT INTO "games" VALUES(416,76,44,463);
# INSERT INTO "games" VALUES(417,1,-965,-665);
# INSERT INTO "games" VALUES(418,26,-818,-609);
# INSERT INTO "games" VALUES(419,77,-90,-539);
# INSERT INTO "games" VALUES(420,44,145,-78);
# INSERT INTO "games" VALUES(421,56,-305,-748);
# INSERT INTO "games" VALUES(422,51,224,-740);
# INSERT INTO "games" VALUES(423,58,896,-428);
# INSERT INTO "games" VALUES(424,69,858,-327);
# INSERT INTO "games" VALUES(425,23,-515,-123);
# INSERT INTO "games" VALUES(426,96,-520,692);
# INSERT INTO "games" VALUES(427,66,753,212);
# INSERT INTO "games" VALUES(428,5,511,-246);
# INSERT INTO "games" VALUES(429,22,-157,967);
# INSERT INTO "games" VALUES(430,58,-689,528);
# INSERT INTO "games" VALUES(431,26,-365,604);
# INSERT INTO "games" VALUES(432,24,-433,775);
# INSERT INTO "games" VALUES(433,15,290,147);
# INSERT INTO "games" VALUES(434,70,972,428);
# INSERT INTO "games" VALUES(435,91,607,-857);
# INSERT INTO "games" VALUES(436,65,-303,253);
# INSERT INTO "games" VALUES(437,76,-91,728);
# INSERT INTO "games" VALUES(438,38,-229,250);
# INSERT INTO "games" VALUES(439,0,930,-684);
# INSERT INTO "games" VALUES(440,3,41,672);
# INSERT INTO "games" VALUES(441,95,120,968);
# INSERT INTO "games" VALUES(442,32,538,-592);
# INSERT INTO "games" VALUES(443,28,41,-746);
# INSERT INTO "games" VALUES(444,59,845,714);
# INSERT INTO "games" VALUES(445,18,-740,-28);
# INSERT INTO "games" VALUES(446,58,165,77);
# INSERT INTO "games" VALUES(447,93,752,-953);
# INSERT INTO "games" VALUES(448,67,-69,238);
# INSERT INTO "games" VALUES(449,22,801,689);
# INSERT INTO "games" VALUES(450,92,176,29);
# INSERT INTO "games" VALUES(451,97,-116,890);
# INSERT INTO "games" VALUES(452,9,-443,569);
# INSERT INTO "games" VALUES(453,74,-411,719);
# INSERT INTO "games" VALUES(454,47,679,-912);
# INSERT INTO "games" VALUES(455,30,-277,153);
# INSERT INTO "games" VALUES(456,87,-594,110);
# INSERT INTO "games" VALUES(457,5,256,-436);
# INSERT INTO "games" VALUES(458,94,749,128);
# INSERT INTO "games" VALUES(459,0,-633,25);
# INSERT INTO "games" VALUES(460,48,228,800);
# INSERT INTO "games" VALUES(461,81,73,269);
# INSERT INTO "games" VALUES(462,3,164,-938);
# INSERT INTO "games" VALUES(463,22,-825,896);
# INSERT INTO "games" VALUES(464,29,-337,975);
# INSERT INTO "games" VALUES(465,21,-317,-223);
# INSERT INTO "games" VALUES(466,85,-596,569);
# INSERT INTO "games" VALUES(467,31,415,528);
# INSERT INTO "games" VALUES(468,8,415,626);
# INSERT INTO "games" VALUES(469,61,-477,579);
# INSERT INTO "games" VALUES(470,23,-379,117);
# INSERT INTO "games" VALUES(471,75,380,-722);
# INSERT INTO "games" VALUES(472,72,-19,364);
# INSERT INTO "games" VALUES(473,27,799,-5);
# INSERT INTO "games" VALUES(474,29,-486,-579);
# INSERT INTO "games" VALUES(475,88,-648,273);
# INSERT INTO "games" VALUES(476,33,94,5);
# INSERT INTO "games" VALUES(477,8,-845,-477);
# INSERT INTO "games" VALUES(478,90,-127,-881);
# INSERT INTO "games" VALUES(479,66,909,-785);
# INSERT INTO "games" VALUES(480,92,542,673);
# INSERT INTO "games" VALUES(481,82,-652,-544);
# INSERT INTO "games" VALUES(482,0,110,488);
# INSERT INTO "games" VALUES(483,44,924,215);
# INSERT INTO "games" VALUES(484,8,-500,224);
# INSERT INTO "games" VALUES(485,10,570,-988);
# INSERT INTO "games" VALUES(486,14,-500,-11);
# INSERT INTO "games" VALUES(487,61,-502,-791);
# INSERT INTO "games" VALUES(488,55,-57,511);
# INSERT INTO "games" VALUES(489,65,935,83);
# INSERT INTO "games" VALUES(490,66,-289,-793);
# INSERT INTO "games" VALUES(491,62,948,-186);
# INSERT INTO "games" VALUES(492,54,-850,871);
# INSERT INTO "games" VALUES(493,24,917,-391);
# INSERT INTO "games" VALUES(494,79,448,-862);
# INSERT INTO "games" VALUES(495,14,881,848);
# INSERT INTO "games" VALUES(496,97,-729,827);
# INSERT INTO "games" VALUES(497,50,-667,877);
# INSERT INTO "games" VALUES(498,30,-201,707);
# INSERT INTO "games" VALUES(499,50,-291,-250);
# INSERT INTO "games" VALUES(500,98,-828,-209);
# INSERT INTO "games" VALUES(501,47,888,-263);
# INSERT INTO "games" VALUES(502,88,706,162);
# INSERT INTO "games" VALUES(503,82,-445,433);
# INSERT INTO "games" VALUES(504,93,-283,-808);
# INSERT INTO "games" VALUES(505,29,-637,87);
# INSERT INTO "games" VALUES(506,63,633,-705);
# INSERT INTO "games" VALUES(507,17,-341,-626);
# INSERT INTO "games" VALUES(508,39,402,-311);
# INSERT INTO "games" VALUES(509,23,607,-168);
# INSERT INTO "games" VALUES(510,60,-801,587);
# INSERT INTO "games" VALUES(511,39,-176,471);
# INSERT INTO "games" VALUES(512,79,580,-641);
# INSERT INTO "games" VALUES(513,31,846,-621);
# INSERT INTO "games" VALUES(514,5,-175,-121);
# INSERT INTO "games" VALUES(515,35,-567,-480);
# INSERT INTO "games" VALUES(516,3,-838,468);
# INSERT INTO "games" VALUES(517,30,826,104);
# INSERT INTO "games" VALUES(518,39,23,924);
# INSERT INTO "games" VALUES(519,74,-657,-846);
# INSERT INTO "games" VALUES(520,2,-154,-629);
# INSERT INTO "games" VALUES(521,7,866,-978);
# INSERT INTO "games" VALUES(522,13,866,-328);
# INSERT INTO "games" VALUES(523,46,930,862);
# INSERT INTO "games" VALUES(524,25,-552,206);
# INSERT INTO "games" VALUES(525,96,-697,-521);
# INSERT INTO "games" VALUES(526,3,-421,38);
# INSERT INTO "games" VALUES(527,36,148,161);
# INSERT INTO "games" VALUES(528,92,615,439);
# INSERT INTO "games" VALUES(529,35,-22,-716);
# INSERT INTO "games" VALUES(530,39,-616,-956);
# INSERT INTO "games" VALUES(531,9,-877,-691);
# INSERT INTO "games" VALUES(532,48,867,884);
# INSERT INTO "games" VALUES(533,12,520,-218);
# INSERT INTO "games" VALUES(534,86,-50,440);
# INSERT INTO "games" VALUES(535,87,-392,683);
# INSERT INTO "games" VALUES(536,88,430,-926);
# INSERT INTO "games" VALUES(537,47,-537,430);
# INSERT INTO "games" VALUES(538,93,380,203);
# INSERT INTO "games" VALUES(539,21,-80,-224);
# INSERT INTO "games" VALUES(540,8,974,24);
# INSERT INTO "games" VALUES(541,56,405,521);
# INSERT INTO "games" VALUES(542,9,452,21);
# INSERT INTO "games" VALUES(543,14,-937,-593);
# INSERT INTO "games" VALUES(544,46,453,373);
# INSERT INTO "games" VALUES(545,66,-328,765);
# INSERT INTO "games" VALUES(546,81,336,810);
# INSERT INTO "games" VALUES(547,27,-26,-688);
# INSERT INTO "games" VALUES(548,3,45,-204);
# INSERT INTO "games" VALUES(549,39,200,-288);
# INSERT INTO "games" VALUES(550,98,119,690);
# INSERT INTO "games" VALUES(551,42,124,391);
# INSERT INTO "games" VALUES(552,90,-761,-836);
# INSERT INTO "games" VALUES(553,85,-786,469);
# INSERT INTO "games" VALUES(554,90,733,204);
# INSERT INTO "games" VALUES(555,46,-333,999);
# INSERT INTO "games" VALUES(556,53,-52,851);
# INSERT INTO "games" VALUES(557,31,-892,620);
# INSERT INTO "games" VALUES(558,84,462,-644);
# INSERT INTO "games" VALUES(559,63,-569,-71);
# INSERT INTO "games" VALUES(560,74,-713,213);
# INSERT INTO "games" VALUES(561,70,470,-647);
# INSERT INTO "games" VALUES(562,21,-710,789);
# INSERT INTO "games" VALUES(563,34,740,831);
# INSERT INTO "games" VALUES(564,93,-563,-735);
# INSERT INTO "games" VALUES(565,6,-708,-783);
# INSERT INTO "games" VALUES(566,93,769,-517);
# INSERT INTO "games" VALUES(567,67,207,172);
# INSERT INTO "games" VALUES(568,69,284,-709);
# INSERT INTO "games" VALUES(569,73,858,609);
# INSERT INTO "games" VALUES(570,19,-570,-670);
# INSERT INTO "games" VALUES(571,75,-807,-344);
# INSERT INTO "games" VALUES(572,81,376,717);
# INSERT INTO "games" VALUES(573,86,522,681);
# INSERT INTO "games" VALUES(574,0,-960,326);
# INSERT INTO "games" VALUES(575,50,-266,-210);
# INSERT INTO "games" VALUES(576,35,401,-477);
# INSERT INTO "games" VALUES(577,80,385,-789);
# INSERT INTO "games" VALUES(578,66,-891,712);
# INSERT INTO "games" VALUES(579,57,966,875);
# INSERT INTO "games" VALUES(580,78,-197,-199);
# INSERT INTO "games" VALUES(581,61,-138,-725);
# INSERT INTO "games" VALUES(582,9,971,244);
# INSERT INTO "games" VALUES(583,81,-338,267);
# INSERT INTO "games" VALUES(584,3,938,361);
# INSERT INTO "games" VALUES(585,38,143,266);
# INSERT INTO "games" VALUES(586,7,-390,-404);
# INSERT INTO "games" VALUES(587,89,995,-601);
# INSERT INTO "games" VALUES(588,96,805,-356);
# INSERT INTO "games" VALUES(589,61,211,-554);
# INSERT INTO "games" VALUES(590,83,-146,-633);
# INSERT INTO "games" VALUES(591,28,-766,562);
# INSERT INTO "games" VALUES(592,5,244,164);
# INSERT INTO "games" VALUES(593,12,-961,545);
# INSERT INTO "games" VALUES(594,89,-607,100);
# INSERT INTO "games" VALUES(595,25,437,77);
# INSERT INTO "games" VALUES(596,87,669,344);
# INSERT INTO "games" VALUES(597,18,-342,832);
# INSERT INTO "games" VALUES(598,99,-287,-111);
# INSERT INTO "games" VALUES(599,19,824,-912);
# INSERT INTO "games" VALUES(600,71,-365,995);
# INSERT INTO "games" VALUES(601,54,-889,308);
# INSERT INTO "games" VALUES(602,78,5,-322);
# INSERT INTO "games" VALUES(603,30,500,38);
# INSERT INTO "games" VALUES(604,7,518,-870);
# INSERT INTO "games" VALUES(605,61,-658,85);
# INSERT INTO "games" VALUES(606,47,-414,646);
# INSERT INTO "games" VALUES(607,90,-195,-729);
# INSERT INTO "games" VALUES(608,75,-573,-176);
# INSERT INTO "games" VALUES(609,82,565,49);
# INSERT INTO "games" VALUES(610,64,-282,-775);
# INSERT INTO "games" VALUES(611,8,-49,-107);
# INSERT INTO "games" VALUES(612,45,-340,-744);
# INSERT INTO "games" VALUES(613,75,873,-354);
# INSERT INTO "games" VALUES(614,70,699,33);
# INSERT INTO "games" VALUES(615,98,-542,-165);
# INSERT INTO "games" VALUES(616,53,152,-680);
# INSERT INTO "games" VALUES(617,91,699,-84);
# INSERT INTO "games" VALUES(618,10,658,-925);
# INSERT INTO "games" VALUES(619,79,-544,-757);
# INSERT INTO "games" VALUES(620,78,539,533);
# INSERT INTO "games" VALUES(621,76,260,-313);
# INSERT INTO "games" VALUES(622,91,740,-585);
# INSERT INTO "games" VALUES(623,99,146,-106);
# INSERT INTO "games" VALUES(624,25,33,692);
# INSERT INTO "games" VALUES(625,20,408,697);
# INSERT INTO "games" VALUES(626,2,-702,579);
# INSERT INTO "games" VALUES(627,80,38,17);
# INSERT INTO "games" VALUES(628,99,87,-756);
# INSERT INTO "games" VALUES(629,22,810,829);
# INSERT INTO "games" VALUES(630,25,-942,142);
# INSERT INTO "games" VALUES(631,57,122,-533);
# INSERT INTO "games" VALUES(632,58,113,-668);
# INSERT INTO "games" VALUES(633,88,824,617);
# INSERT INTO "games" VALUES(634,72,-124,591);
# INSERT INTO "games" VALUES(635,51,161,-100);
# INSERT INTO "games" VALUES(636,16,-977,576);
# INSERT INTO "games" VALUES(637,39,-209,763);
# INSERT INTO "games" VALUES(638,77,459,511);
# INSERT INTO "games" VALUES(639,83,-947,-748);
# INSERT INTO "games" VALUES(640,31,-225,-485);
# INSERT INTO "games" VALUES(641,36,106,905);
# INSERT INTO "games" VALUES(642,68,-463,208);
# INSERT INTO "games" VALUES(643,47,-51,-218);
# INSERT INTO "games" VALUES(644,0,68,253);
# INSERT INTO "games" VALUES(645,9,234,-880);
# INSERT INTO "games" VALUES(646,50,41,-605);
# INSERT INTO "games" VALUES(647,70,343,219);
# INSERT INTO "games" VALUES(648,53,-679,822);
# INSERT INTO "games" VALUES(649,77,-219,828);
# INSERT INTO "games" VALUES(650,72,621,455);
# INSERT INTO "games" VALUES(651,64,-380,153);
# INSERT INTO "games" VALUES(652,38,727,174);
# INSERT INTO "games" VALUES(653,83,21,-781);
# INSERT INTO "games" VALUES(654,16,-16,-508);
# INSERT INTO "games" VALUES(655,24,619,597);
# INSERT INTO "games" VALUES(656,52,-34,-430);
# INSERT INTO "games" VALUES(657,3,84,537);
# INSERT INTO "games" VALUES(658,46,783,934);
# INSERT INTO "games" VALUES(659,63,970,576);
# INSERT INTO "games" VALUES(660,35,-96,610);
# INSERT INTO "games" VALUES(661,5,845,792);
# INSERT INTO "games" VALUES(662,71,528,51);
# INSERT INTO "games" VALUES(663,31,844,147);
# INSERT INTO "games" VALUES(664,43,-625,-773);
# INSERT INTO "games" VALUES(665,24,-904,-578);
# INSERT INTO "games" VALUES(666,65,-872,140);
# INSERT INTO "games" VALUES(667,37,-571,290);
# INSERT INTO "games" VALUES(668,58,201,-668);
# INSERT INTO "games" VALUES(669,78,-277,356);
# INSERT INTO "games" VALUES(670,43,-451,-353);
# INSERT INTO "games" VALUES(671,82,390,629);
# INSERT INTO "games" VALUES(672,54,380,-343);
# INSERT INTO "games" VALUES(673,0,-793,-465);
# INSERT INTO "games" VALUES(674,77,-46,-991);
# INSERT INTO "games" VALUES(675,91,487,-701);
# INSERT INTO "games" VALUES(676,17,109,-300);
# INSERT INTO "games" VALUES(677,97,-287,-455);
# INSERT INTO "games" VALUES(678,21,-62,233);
# INSERT INTO "games" VALUES(679,1,12,-581);
# INSERT INTO "games" VALUES(680,5,-274,-89);
# INSERT INTO "games" VALUES(681,39,-422,-705);
# INSERT INTO "games" VALUES(682,95,-18,717);
# INSERT INTO "games" VALUES(683,98,-932,205);
# INSERT INTO "games" VALUES(684,24,15,-551);
# INSERT INTO "games" VALUES(685,17,991,-845);
# INSERT INTO "games" VALUES(686,29,892,162);
# INSERT INTO "games" VALUES(687,92,382,940);
# INSERT INTO "games" VALUES(688,40,-254,197);
# INSERT INTO "games" VALUES(689,33,-998,-462);
# INSERT INTO "games" VALUES(690,81,247,-556);
# INSERT INTO "games" VALUES(691,79,-696,-261);
# INSERT INTO "games" VALUES(692,15,-642,-437);
# INSERT INTO "games" VALUES(693,51,-486,346);
# INSERT INTO "games" VALUES(694,0,-747,-474);
# INSERT INTO "games" VALUES(695,69,638,460);
# INSERT INTO "games" VALUES(696,69,-267,820);
# INSERT INTO "games" VALUES(697,50,-790,-560);
# INSERT INTO "games" VALUES(698,26,903,-920);
# INSERT INTO "games" VALUES(699,30,404,-55);
# INSERT INTO "games" VALUES(700,16,-652,559);
# INSERT INTO "games" VALUES(701,71,-896,822);
# INSERT INTO "games" VALUES(702,52,859,20);
# INSERT INTO "games" VALUES(703,67,618,-817);
# INSERT INTO "games" VALUES(704,83,-457,314);
# INSERT INTO "games" VALUES(705,89,-685,345);
# INSERT INTO "games" VALUES(706,76,-39,-608);
# INSERT INTO "games" VALUES(707,68,586,1000);
# INSERT INTO "games" VALUES(708,71,-858,-142);
# INSERT INTO "games" VALUES(709,37,631,-609);
# INSERT INTO "games" VALUES(710,43,-352,-855);
# INSERT INTO "games" VALUES(711,43,-881,-738);
# INSERT INTO "games" VALUES(712,85,-743,202);
# INSERT INTO "games" VALUES(713,11,-446,436);
# INSERT INTO "games" VALUES(714,36,298,-43);
# INSERT INTO "games" VALUES(715,14,-793,120);
# INSERT INTO "games" VALUES(716,85,-192,852);
# INSERT INTO "games" VALUES(717,90,91,30);
# INSERT INTO "games" VALUES(718,85,-405,198);
# INSERT INTO "games" VALUES(719,61,-548,300);
# INSERT INTO "games" VALUES(720,16,-248,498);
# INSERT INTO "games" VALUES(721,79,793,-723);
# INSERT INTO "games" VALUES(722,79,902,-763);
# INSERT INTO "games" VALUES(723,14,-865,-425);
# INSERT INTO "games" VALUES(724,51,19,292);
# INSERT INTO "games" VALUES(725,95,741,964);
# INSERT INTO "games" VALUES(726,93,293,-405);
# INSERT INTO "games" VALUES(727,23,-94,-937);
# INSERT INTO "games" VALUES(728,98,-861,-1000);
# INSERT INTO "games" VALUES(729,1,-26,830);
# INSERT INTO "games" VALUES(730,10,-283,-881);
# INSERT INTO "games" VALUES(731,36,-113,345);
# INSERT INTO "games" VALUES(732,58,774,427);
# INSERT INTO "games" VALUES(733,63,-160,-895);
# INSERT INTO "games" VALUES(734,33,-824,-8);
# INSERT INTO "games" VALUES(735,88,-445,-182);
# INSERT INTO "games" VALUES(736,46,105,335);
# INSERT INTO "games" VALUES(737,21,298,-293);
# INSERT INTO "games" VALUES(738,11,-877,-504);
# INSERT INTO "games" VALUES(739,33,-828,-929);
# INSERT INTO "games" VALUES(740,53,-56,547);
# INSERT INTO "games" VALUES(741,13,-177,-150);
# INSERT INTO "games" VALUES(742,52,364,-895);
# INSERT INTO "games" VALUES(743,48,-625,639);
# INSERT INTO "games" VALUES(744,87,-719,98);
# INSERT INTO "games" VALUES(745,15,749,940);
# INSERT INTO "games" VALUES(746,9,19,443);
# INSERT INTO "games" VALUES(747,64,-778,140);
# INSERT INTO "games" VALUES(748,15,-206,398);
# INSERT INTO "games" VALUES(749,70,133,-452);
# INSERT INTO "games" VALUES(750,17,-194,-7);
# INSERT INTO "games" VALUES(751,88,676,-570);
# INSERT INTO "games" VALUES(752,47,213,-244);
# INSERT INTO "games" VALUES(753,79,-420,-420);
# INSERT INTO "games" VALUES(754,26,-871,93);
# INSERT INTO "games" VALUES(755,25,450,343);
# INSERT INTO "games" VALUES(756,75,-415,65);
# INSERT INTO "games" VALUES(757,7,106,-383);
# INSERT INTO "games" VALUES(758,74,645,-820);
# INSERT INTO "games" VALUES(759,35,-437,398);
# INSERT INTO "games" VALUES(760,57,-661,466);
# INSERT INTO "games" VALUES(761,10,-612,-459);
# INSERT INTO "games" VALUES(762,77,-109,633);
# INSERT INTO "games" VALUES(763,85,-691,903);
# INSERT INTO "games" VALUES(764,13,-940,494);
# INSERT INTO "games" VALUES(765,18,217,-464);
# INSERT INTO "games" VALUES(766,58,89,-205);
# INSERT INTO "games" VALUES(767,80,43,680);
# INSERT INTO "games" VALUES(768,89,-652,-437);
# INSERT INTO "games" VALUES(769,56,405,457);
# INSERT INTO "games" VALUES(770,92,-10,-467);
# INSERT INTO "games" VALUES(771,93,766,-704);
# INSERT INTO "games" VALUES(772,79,156,-646);
# INSERT INTO "games" VALUES(773,46,577,656);
# INSERT INTO "games" VALUES(774,83,-920,403);
# INSERT INTO "games" VALUES(775,57,393,-374);
# INSERT INTO "games" VALUES(776,7,-556,244);
# INSERT INTO "games" VALUES(777,92,12,472);
# INSERT INTO "games" VALUES(778,76,-801,431);
# INSERT INTO "games" VALUES(779,43,163,-115);
# INSERT INTO "games" VALUES(780,20,-913,582);
# INSERT INTO "games" VALUES(781,13,916,937);
# INSERT INTO "games" VALUES(782,59,811,767);
# INSERT INTO "games" VALUES(783,89,160,803);
# INSERT INTO "games" VALUES(784,41,963,351);
# INSERT INTO "games" VALUES(785,0,339,-727);
# INSERT INTO "games" VALUES(786,30,-917,-904);
# INSERT INTO "games" VALUES(787,59,899,705);
# INSERT INTO "games" VALUES(788,24,526,-260);
# INSERT INTO "games" VALUES(789,15,-474,747);
# INSERT INTO "games" VALUES(790,43,-133,-34);
# INSERT INTO "games" VALUES(791,98,-429,-771);
# INSERT INTO "games" VALUES(792,54,439,192);
# INSERT INTO "games" VALUES(793,29,-215,998);
# INSERT INTO "games" VALUES(794,29,121,-188);
# INSERT INTO "games" VALUES(795,28,-663,158);
# INSERT INTO "games" VALUES(796,64,-977,601);
# INSERT INTO "games" VALUES(797,58,651,401);
# INSERT INTO "games" VALUES(798,58,-600,-64);
# INSERT INTO "games" VALUES(799,40,151,298);
# INSERT INTO "games" VALUES(800,36,-16,444);
# INSERT INTO "games" VALUES(801,53,313,735);
# INSERT INTO "games" VALUES(802,74,977,351);
# INSERT INTO "games" VALUES(803,32,-627,-828);
# INSERT INTO "games" VALUES(804,11,135,-824);
# INSERT INTO "games" VALUES(805,87,-698,-659);
# INSERT INTO "games" VALUES(806,49,668,-465);
# INSERT INTO "games" VALUES(807,7,-424,957);
# INSERT INTO "games" VALUES(808,34,655,787);
# INSERT INTO "games" VALUES(809,87,418,788);
# INSERT INTO "games" VALUES(810,53,501,-734);
# INSERT INTO "games" VALUES(811,23,-951,864);
# INSERT INTO "games" VALUES(812,66,83,582);
# INSERT INTO "games" VALUES(813,4,-594,-966);
# INSERT INTO "games" VALUES(814,84,-47,844);
# INSERT INTO "games" VALUES(815,6,512,-893);
# INSERT INTO "games" VALUES(816,29,692,-917);
# INSERT INTO "games" VALUES(817,1,-335,-814);
# INSERT INTO "games" VALUES(818,56,-191,425);
# INSERT INTO "games" VALUES(819,31,867,755);
# INSERT INTO "games" VALUES(820,67,-586,-582);
# INSERT INTO "games" VALUES(821,75,-413,-411);
# INSERT INTO "games" VALUES(822,59,-15,-514);
# INSERT INTO "games" VALUES(823,6,602,-724);
# INSERT INTO "games" VALUES(824,12,88,-855);
# INSERT INTO "games" VALUES(825,62,677,384);
# INSERT INTO "games" VALUES(826,22,801,702);
# INSERT INTO "games" VALUES(827,27,997,116);
# INSERT INTO "games" VALUES(828,57,-860,239);
# INSERT INTO "games" VALUES(829,75,52,588);
# INSERT INTO "games" VALUES(830,17,-384,-35);
# INSERT INTO "games" VALUES(831,62,801,-362);
# INSERT INTO "games" VALUES(832,39,298,-951);
# INSERT INTO "games" VALUES(833,85,733,696);
# INSERT INTO "games" VALUES(834,65,705,284);
# INSERT INTO "games" VALUES(835,28,-576,151);
# INSERT INTO "games" VALUES(836,50,-661,-965);
# INSERT INTO "games" VALUES(837,32,204,599);
# INSERT INTO "games" VALUES(838,61,26,527);
# INSERT INTO "games" VALUES(839,70,897,890);
# INSERT INTO "games" VALUES(840,29,89,274);
# INSERT INTO "games" VALUES(841,45,224,564);
# INSERT INTO "games" VALUES(842,41,-920,-555);
# INSERT INTO "games" VALUES(843,73,-726,-709);
# INSERT INTO "games" VALUES(844,70,-780,-471);
# INSERT INTO "games" VALUES(845,48,-351,315);
# INSERT INTO "games" VALUES(846,23,-438,-279);
# INSERT INTO "games" VALUES(847,100,25,-603);
# INSERT INTO "games" VALUES(848,16,-236,467);
# INSERT INTO "games" VALUES(849,47,-408,-939);
# INSERT INTO "games" VALUES(850,28,51,87);
# INSERT INTO "games" VALUES(851,18,-641,836);
# INSERT INTO "games" VALUES(852,44,-736,134);
# INSERT INTO "games" VALUES(853,51,-657,393);
# INSERT INTO "games" VALUES(854,73,-355,-237);
# INSERT INTO "games" VALUES(855,96,-712,-92);
# INSERT INTO "games" VALUES(856,2,695,-579);
# INSERT INTO "games" VALUES(857,14,793,-107);
# INSERT INTO "games" VALUES(858,19,-49,859);
# INSERT INTO "games" VALUES(859,5,-538,340);
# INSERT INTO "games" VALUES(860,24,954,460);
# INSERT INTO "games" VALUES(861,50,-319,426);
# INSERT INTO "games" VALUES(862,55,857,866);
# INSERT INTO "games" VALUES(863,64,-301,355);
# INSERT INTO "games" VALUES(864,38,-337,774);
# INSERT INTO "games" VALUES(865,80,-395,939);
# INSERT INTO "games" VALUES(866,42,-377,63);
# INSERT INTO "games" VALUES(867,55,-960,-869);
# INSERT INTO "games" VALUES(868,79,554,-733);
# INSERT INTO "games" VALUES(869,27,53,-477);
# INSERT INTO "games" VALUES(870,30,-431,852);
# INSERT INTO "games" VALUES(871,60,-743,287);
# INSERT INTO "games" VALUES(872,19,-668,-550);
# INSERT INTO "games" VALUES(873,30,-10,-473);
# INSERT INTO "games" VALUES(874,79,-183,-953);
# INSERT INTO "games" VALUES(875,55,12,-618);
# INSERT INTO "games" VALUES(876,30,140,-769);
# INSERT INTO "games" VALUES(877,30,167,-271);
# INSERT INTO "games" VALUES(878,54,77,761);
# INSERT INTO "games" VALUES(879,49,267,656);
# INSERT INTO "games" VALUES(880,8,550,-943);
# INSERT INTO "games" VALUES(881,55,-498,193);
# INSERT INTO "games" VALUES(882,67,994,-116);
# INSERT INTO "games" VALUES(883,59,-207,-238);
# INSERT INTO "games" VALUES(884,90,157,-681);
# INSERT INTO "games" VALUES(885,59,-380,-50);
# INSERT INTO "games" VALUES(886,15,-973,-281);
# INSERT INTO "games" VALUES(887,81,871,669);
# INSERT INTO "games" VALUES(888,100,452,-610);
# INSERT INTO "games" VALUES(889,73,17,-544);
# INSERT INTO "games" VALUES(890,54,-5,-689);
# INSERT INTO "games" VALUES(891,87,625,622);
# INSERT INTO "games" VALUES(892,9,-987,-768);
# INSERT INTO "games" VALUES(893,60,900,153);
# INSERT INTO "games" VALUES(894,96,237,112);
# INSERT INTO "games" VALUES(895,65,-947,-393);
# INSERT INTO "games" VALUES(896,78,-314,-424);
# INSERT INTO "games" VALUES(897,12,-824,613);
# INSERT INTO "games" VALUES(898,64,-662,425);
# INSERT INTO "games" VALUES(899,15,853,659);
# INSERT INTO "games" VALUES(900,16,512,-117);
# INSERT INTO "games" VALUES(901,61,-424,21);
# INSERT INTO "games" VALUES(902,71,-792,-843);
# INSERT INTO "games" VALUES(903,32,267,23);
# INSERT INTO "games" VALUES(904,71,-310,769);
# INSERT INTO "games" VALUES(905,73,-895,494);
# INSERT INTO "games" VALUES(906,13,10,903);
# INSERT INTO "games" VALUES(907,13,-406,-759);
# INSERT INTO "games" VALUES(908,54,457,-369);
# INSERT INTO "games" VALUES(909,31,-101,495);
# INSERT INTO "games" VALUES(910,42,607,409);
# INSERT INTO "games" VALUES(911,33,-776,-901);
# INSERT INTO "games" VALUES(912,72,-428,443);
# INSERT INTO "games" VALUES(913,0,-264,902);
# INSERT INTO "games" VALUES(914,59,-348,982);
# INSERT INTO "games" VALUES(915,41,-657,-548);
# INSERT INTO "games" VALUES(916,19,428,34);
# INSERT INTO "games" VALUES(917,8,417,-537);
# INSERT INTO "games" VALUES(918,5,-852,-883);
# INSERT INTO "games" VALUES(919,95,132,28);
# INSERT INTO "games" VALUES(920,62,-562,484);
# INSERT INTO "games" VALUES(921,11,203,310);
# INSERT INTO "games" VALUES(922,69,611,-169);
# INSERT INTO "games" VALUES(923,13,690,-208);
# INSERT INTO "games" VALUES(924,98,651,-403);
# INSERT INTO "games" VALUES(925,96,-639,614);
# INSERT INTO "games" VALUES(926,72,-731,531);
# INSERT INTO "games" VALUES(927,20,-618,875);
# INSERT INTO "games" VALUES(928,4,771,316);
# INSERT INTO "games" VALUES(929,73,-164,753);
# INSERT INTO "games" VALUES(930,99,881,241);
# INSERT INTO "games" VALUES(931,25,-855,974);
# INSERT INTO "games" VALUES(932,18,980,796);
# INSERT INTO "games" VALUES(933,52,208,332);
# INSERT INTO "games" VALUES(934,7,-873,15);
# INSERT INTO "games" VALUES(935,38,-51,-355);
# INSERT INTO "games" VALUES(936,61,-391,591);
# INSERT INTO "games" VALUES(937,54,-886,120);
# INSERT INTO "games" VALUES(938,12,148,607);
# INSERT INTO "games" VALUES(939,80,205,-28);
# INSERT INTO "games" VALUES(940,100,-229,738);
# INSERT INTO "games" VALUES(941,51,-597,483);
# INSERT INTO "games" VALUES(942,9,-259,-990);
# INSERT INTO "games" VALUES(943,83,-358,347);
# INSERT INTO "games" VALUES(944,57,-358,-967);
# INSERT INTO "games" VALUES(945,60,-364,281);
# INSERT INTO "games" VALUES(946,44,937,-590);
# INSERT INTO "games" VALUES(947,6,-375,298);
# INSERT INTO "games" VALUES(948,66,126,-304);
# INSERT INTO "games" VALUES(949,94,43,-220);
# INSERT INTO "games" VALUES(950,6,-177,-265);
# INSERT INTO "games" VALUES(951,54,624,756);
# INSERT INTO "games" VALUES(952,60,-739,623);
# INSERT INTO "games" VALUES(953,11,383,508);
# INSERT INTO "games" VALUES(954,88,846,390);
# INSERT INTO "games" VALUES(955,82,886,431);
# INSERT INTO "games" VALUES(956,48,-304,-277);
# INSERT INTO "games" VALUES(957,13,485,-915);
# INSERT INTO "games" VALUES(958,55,875,-302);
# INSERT INTO "games" VALUES(959,26,43,-808);
# INSERT INTO "games" VALUES(960,67,-448,326);
# INSERT INTO "games" VALUES(961,51,-99,466);
# INSERT INTO "games" VALUES(962,79,-592,-716);
# INSERT INTO "games" VALUES(963,21,796,-936);
# INSERT INTO "games" VALUES(964,38,-838,-454);
# INSERT INTO "games" VALUES(965,50,-204,-73);
# INSERT INTO "games" VALUES(966,26,224,265);
# INSERT INTO "games" VALUES(967,74,-782,-612);
# INSERT INTO "games" VALUES(968,34,-391,336);
# INSERT INTO "games" VALUES(969,71,983,-90);
# INSERT INTO "games" VALUES(970,26,-143,-289);
# INSERT INTO "games" VALUES(971,79,14,-895);
# INSERT INTO "games" VALUES(972,12,139,420);
# INSERT INTO "games" VALUES(973,56,902,-751);
# INSERT INTO "games" VALUES(974,79,606,-612);
# INSERT INTO "games" VALUES(975,27,-773,-310);
# INSERT INTO "games" VALUES(976,97,66,42);
# INSERT INTO "games" VALUES(977,23,-821,-293);
# INSERT INTO "games" VALUES(978,85,323,-367);
# INSERT INTO "games" VALUES(979,70,156,-753);
# INSERT INTO "games" VALUES(980,64,-38,322);
# INSERT INTO "games" VALUES(981,26,-672,433);
# INSERT INTO "games" VALUES(982,50,253,735);
# INSERT INTO "games" VALUES(983,7,56,-257);
# INSERT INTO "games" VALUES(984,57,80,49);
# INSERT INTO "games" VALUES(985,73,-494,971);
# INSERT INTO "games" VALUES(986,53,-724,-739);
# INSERT INTO "games" VALUES(987,37,827,-740);
# INSERT INTO "games" VALUES(988,68,707,874);
# INSERT INTO "games" VALUES(989,70,173,-534);
# INSERT INTO "games" VALUES(990,83,-367,-633);
# INSERT INTO "games" VALUES(991,12,-747,674);
# INSERT INTO "games" VALUES(992,74,185,400);
# INSERT INTO "games" VALUES(993,1,-230,-507);
# INSERT INTO "games" VALUES(994,57,-190,-8);
# INSERT INTO "games" VALUES(995,47,349,616);
# INSERT INTO "games" VALUES(996,70,452,420);
# INSERT INTO "games" VALUES(997,87,539,54);
# INSERT INTO "games" VALUES(998,33,-988,416);
# INSERT INTO "games" VALUES(999,81,188,157);
# INSERT INTO "games" VALUES(1000,34,-663,329);
# INSERT INTO "games" VALUES(1001,219,-798,-872);
# INSERT INTO "games" VALUES(1002,942,-376,947);
# INSERT INTO "games" VALUES(1003,165,264,-488);
# INSERT INTO "games" VALUES(1004,658,-15,-50);
# INSERT INTO "games" VALUES(1005,768,-729,584);
# INSERT INTO "games" VALUES(1006,344,211,-908);
# INSERT INTO "games" VALUES(1007,123,-472,-572);
# INSERT INTO "games" VALUES(1008,254,-253,758);
# INSERT INTO "games" VALUES(1009,464,547,-351);
# INSERT INTO "games" VALUES(1010,781,444,-450);
# INSERT INTO "games" VALUES(1011,319,968,623);
# INSERT INTO "games" VALUES(1012,276,-478,910);
# INSERT INTO "games" VALUES(1013,483,-511,70);
# INSERT INTO "games" VALUES(1014,933,-512,-713);
# INSERT INTO "games" VALUES(1015,839,162,981);
# INSERT INTO "games" VALUES(1016,876,-282,-306);
# INSERT INTO "games" VALUES(1017,108,-863,-507);
# INSERT INTO "games" VALUES(1018,395,-146,873);
# INSERT INTO "games" VALUES(1019,940,-298,966);
# INSERT INTO "games" VALUES(1020,498,-448,-771);
# INSERT INTO "games" VALUES(1021,595,-236,-952);
# INSERT INTO "games" VALUES(1022,704,848,-650);
# INSERT INTO "games" VALUES(1023,382,-445,-852);
# INSERT INTO "games" VALUES(1024,238,-206,659);
# INSERT INTO "games" VALUES(1025,507,391,514);
# INSERT INTO "games" VALUES(1026,452,236,385);
# INSERT INTO "games" VALUES(1027,806,-790,-635);
# INSERT INTO "games" VALUES(1028,851,795,336);
# INSERT INTO "games" VALUES(1029,805,-481,-855);
# INSERT INTO "games" VALUES(1030,262,-217,804);
# INSERT INTO "games" VALUES(1031,609,715,-440);
# INSERT INTO "games" VALUES(1032,738,543,463);
# INSERT INTO "games" VALUES(1033,645,505,648);
# INSERT INTO "games" VALUES(1034,684,343,794);
# INSERT INTO "games" VALUES(1035,575,-555,725);
# INSERT INTO "games" VALUES(1036,308,32,-447);
# INSERT INTO "games" VALUES(1037,294,472,-843);
# INSERT INTO "games" VALUES(1038,494,429,645);
# INSERT INTO "games" VALUES(1039,955,-169,7);
# INSERT INTO "games" VALUES(1040,417,-898,-982);
# INSERT INTO "games" VALUES(1041,528,761,513);
# INSERT INTO "games" VALUES(1042,575,-289,-822);
# INSERT INTO "games" VALUES(1043,747,59,-246);
# INSERT INTO "games" VALUES(1044,985,680,74);
# INSERT INTO "games" VALUES(1045,280,-534,-593);
# INSERT INTO "games" VALUES(1046,590,162,831);
# INSERT INTO "games" VALUES(1047,833,781,-374);
# INSERT INTO "games" VALUES(1048,693,282,368);
# INSERT INTO "games" VALUES(1049,496,239,-209);
# INSERT INTO "games" VALUES(1050,960,-234,203);
# INSERT INTO "games" VALUES(1051,185,-769,641);
# INSERT INTO "games" VALUES(1052,361,-191,233);
# INSERT INTO "games" VALUES(1053,658,-611,598);
# INSERT INTO "games" VALUES(1054,289,-307,-125);
# ...
# INSERT INTO "user" VALUES(7900,'Some Guy','someone@gmail.com',403,1,580,-608);
# INSERT INTO "user" VALUES(7901,'Some Guy','someone@gmail.com',362,1,339,-770);
# INSERT INTO "user" VALUES(7902,'Some Guy','someone@gmail.com',526,1,251,13);
# INSERT INTO "user" VALUES(7903,'Some Guy','someone@gmail.com',154,1,545,679);
# INSERT INTO "user" VALUES(7904,'Some Guy','someone@gmail.com',338,1,393,335);
# INSERT INTO "user" VALUES(7905,'Some Guy','someone@gmail.com',527,1,118,-769);
# INSERT INTO "user" VALUES(7906,'Some Guy','someone@gmail.com',271,1,933,-31);
# INSERT INTO "user" VALUES(7907,'Some Guy','someone@gmail.com',720,1,144,-737);
# INSERT INTO "user" VALUES(7908,'Some Guy','someone@gmail.com',643,1,450,-557);
# INSERT INTO "user" VALUES(7909,'Some Guy','someone@gmail.com',848,1,582,378);
# INSERT INTO "user" VALUES(7910,'Some Guy','someone@gmail.com',952,1,274,559);
# INSERT INTO "user" VALUES(7911,'Some Guy','someone@gmail.com',151,1,369,923);
# INSERT INTO "user" VALUES(7912,'Some Guy','someone@gmail.com',746,1,172,129);
# INSERT INTO "user" VALUES(7913,'Some Guy','someone@gmail.com',974,1,519,-722);
# INSERT INTO "user" VALUES(7914,'Some Guy','someone@gmail.com',603,1,680,422);
# INSERT INTO "user" VALUES(7915,'Some Guy','someone@gmail.com',751,1,255,528);
# INSERT INTO "user" VALUES(7916,'Some Guy','someone@gmail.com',803,1,241,560);
# INSERT INTO "user" VALUES(7917,'Some Guy','someone@gmail.com',996,1,439,-370);
# INSERT INTO "user" VALUES(7918,'Some Guy','someone@gmail.com',308,1,912,995);
# INSERT INTO "user" VALUES(7919,'Some Guy','someone@gmail.com',976,1,713,934);
# INSERT INTO "user" VALUES(7920,'Some Guy','someone@gmail.com',520,1,900,562);
# INSERT INTO "user" VALUES(7921,'Some Guy','someone@gmail.com',528,1,79,625);
# INSERT INTO "user" VALUES(7922,'Some Guy','someone@gmail.com',451,1,68,-212);
# INSERT INTO "user" VALUES(7923,'Some Guy','someone@gmail.com',602,1,42,-709);
# INSERT INTO "user" VALUES(7924,'Some Guy','someone@gmail.com',694,1,159,86);
# INSERT INTO "user" VALUES(7925,'Some Guy','someone@gmail.com',833,1,703,-395);
# INSERT INTO "user" VALUES(7926,'Some Guy','someone@gmail.com',355,1,294,-333);
# INSERT INTO "user" VALUES(7927,'Some Guy','someone@gmail.com',689,1,637,-280);
# INSERT INTO "user" VALUES(7928,'Some Guy','someone@gmail.com',993,1,301,530);
# INSERT INTO "user" VALUES(7929,'Some Guy','someone@gmail.com',322,1,855,-207);
# INSERT INTO "user" VALUES(7930,'Some Guy','someone@gmail.com',339,1,700,864);
# INSERT INTO "user" VALUES(7931,'Some Guy','someone@gmail.com',565,1,926,-52);
# INSERT INTO "user" VALUES(7932,'Some Guy','someone@gmail.com',982,1,95,390);
# INSERT INTO "user" VALUES(7933,'Some Guy','someone@gmail.com',357,1,396,-427);
# INSERT INTO "user" VALUES(7934,'Some Guy','someone@gmail.com',485,1,688,527);
# INSERT INTO "user" VALUES(7935,'Some Guy','someone@gmail.com',755,1,642,988);
# INSERT INTO "user" VALUES(7936,'Some Guy','someone@gmail.com',195,1,255,-334);
# INSERT INTO "user" VALUES(7937,'Some Guy','someone@gmail.com',801,1,947,-834);
# INSERT INTO "user" VALUES(7938,'Some Guy','someone@gmail.com',139,1,18,-524);
# INSERT INTO "user" VALUES(7939,'Some Guy','someone@gmail.com',993,1,694,-152);
# INSERT INTO "user" VALUES(7940,'Some Guy','someone@gmail.com',927,1,242,310);
# INSERT INTO "user" VALUES(7941,'Some Guy','someone@gmail.com',305,1,127,-153);
# INSERT INTO "user" VALUES(7942,'Some Guy','someone@gmail.com',205,1,946,489);
# INSERT INTO "user" VALUES(7943,'Some Guy','someone@gmail.com',395,1,948,-354);
# INSERT INTO "user" VALUES(7944,'Some Guy','someone@gmail.com',177,1,548,-764);
# INSERT INTO "user" VALUES(7945,'Some Guy','someone@gmail.com',499,1,567,900);
# INSERT INTO "user" VALUES(7946,'Some Guy','someone@gmail.com',739,1,385,-916);
# INSERT INTO "user" VALUES(7947,'Some Guy','someone@gmail.com',568,1,462,-91);
# INSERT INTO "user" VALUES(7948,'Some Guy','someone@gmail.com',896,1,402,-681);
# INSERT INTO "user" VALUES(7949,'Some Guy','someone@gmail.com',701,1,380,-683);
# INSERT INTO "user" VALUES(7950,'Some Guy','someone@gmail.com',710,1,386,39);
# INSERT INTO "user" VALUES(7951,'Some Guy','someone@gmail.com',508,1,85,-798);
# INSERT INTO "user" VALUES(7952,'Some Guy','someone@gmail.com',243,1,167,-527);
# INSERT INTO "user" VALUES(7953,'Some Guy','someone@gmail.com',198,1,727,-127);
# INSERT INTO "user" VALUES(7954,'Some Guy','someone@gmail.com',227,1,293,-761);
# INSERT INTO "user" VALUES(7955,'Some Guy','someone@gmail.com',733,1,265,39);
# INSERT INTO "user" VALUES(7956,'Some Guy','someone@gmail.com',335,1,322,-166);
# INSERT INTO "user" VALUES(7957,'Some Guy','someone@gmail.com',619,1,994,-180);
# INSERT INTO "user" VALUES(7958,'Some Guy','someone@gmail.com',205,1,337,-840);
# INSERT INTO "user" VALUES(7959,'Some Guy','someone@gmail.com',985,1,176,-802);
# INSERT INTO "user" VALUES(7960,'Some Guy','someone@gmail.com',113,1,495,748);
# INSERT INTO "user" VALUES(7961,'Some Guy','someone@gmail.com',312,1,476,-9);
# INSERT INTO "user" VALUES(7962,'Some Guy','someone@gmail.com',891,1,144,-906);
# INSERT INTO "user" VALUES(7963,'Some Guy','someone@gmail.com',396,1,812,-485);
# INSERT INTO "user" VALUES(7964,'Some Guy','someone@gmail.com',809,1,839,-320);
# INSERT INTO "user" VALUES(7965,'Some Guy','someone@gmail.com',148,1,857,-638);
# INSERT INTO "user" VALUES(7966,'Some Guy','someone@gmail.com',729,1,673,863);
# INSERT INTO "user" VALUES(7967,'Some Guy','someone@gmail.com',235,1,607,521);
# INSERT INTO "user" VALUES(7968,'Some Guy','someone@gmail.com',243,1,745,543);
# INSERT INTO "user" VALUES(7969,'Some Guy','someone@gmail.com',818,1,428,-323);
# INSERT INTO "user" VALUES(7970,'Some Guy','someone@gmail.com',585,1,188,-338);
# INSERT INTO "user" VALUES(7971,'Some Guy','someone@gmail.com',958,1,605,668);
# INSERT INTO "user" VALUES(7972,'Some Guy','someone@gmail.com',489,1,90,-443);
# INSERT INTO "user" VALUES(7973,'Some Guy','someone@gmail.com',210,1,440,-150);
# INSERT INTO "user" VALUES(7974,'Some Guy','someone@gmail.com',652,1,886,-660);
# INSERT INTO "user" VALUES(7975,'Some Guy','someone@gmail.com',639,1,34,259);
# INSERT INTO "user" VALUES(7976,'Some Guy','someone@gmail.com',107,1,198,-222);
# INSERT INTO "user" VALUES(7977,'Some Guy','someone@gmail.com',794,1,874,-90);
# INSERT INTO "user" VALUES(7978,'Some Guy','someone@gmail.com',387,1,778,681);
# INSERT INTO "user" VALUES(7979,'Some Guy','someone@gmail.com',343,1,239,740);
# INSERT INTO "user" VALUES(7980,'Some Guy','someone@gmail.com',774,1,806,129);
# INSERT INTO "user" VALUES(7981,'Some Guy','someone@gmail.com',565,1,543,956);
# INSERT INTO "user" VALUES(7982,'Some Guy','someone@gmail.com',324,1,467,-520);
# INSERT INTO "user" VALUES(7983,'Some Guy','someone@gmail.com',776,1,537,572);
# INSERT INTO "user" VALUES(7984,'Some Guy','someone@gmail.com',533,1,222,-907);
# INSERT INTO "user" VALUES(7985,'Some Guy','someone@gmail.com',673,1,886,298);
# INSERT INTO "user" VALUES(7986,'Some Guy','someone@gmail.com',889,1,810,-323);
# INSERT INTO "user" VALUES(7987,'Some Guy','someone@gmail.com',947,1,836,-429);
# INSERT INTO "user" VALUES(7988,'Some Guy','someone@gmail.com',282,1,12,-719);
# INSERT INTO "user" VALUES(7989,'Some Guy','someone@gmail.com',649,1,723,-743);
# INSERT INTO "user" VALUES(7990,'Some Guy','someone@gmail.com',208,1,421,459);
# INSERT INTO "user" VALUES(7991,'Some Guy','someone@gmail.com',998,1,438,-41);
# INSERT INTO "user" VALUES(7992,'Some Guy','someone@gmail.com',580,1,760,-89);
# INSERT INTO "user" VALUES(7993,'Some Guy','someone@gmail.com',273,1,335,-844);
# INSERT INTO "user" VALUES(7994,'Some Guy','someone@gmail.com',207,1,286,460);
# INSERT INTO "user" VALUES(7995,'Some Guy','someone@gmail.com',630,1,573,929);
# INSERT INTO "user" VALUES(7996,'Some Guy','someone@gmail.com',877,1,765,683);
# INSERT INTO "user" VALUES(7997,'Some Guy','someone@gmail.com',133,1,120,13);
# INSERT INTO "user" VALUES(7998,'Some Guy','someone@gmail.com',698,1,435,911);
# INSERT INTO "user" VALUES(7999,'Some Guy','someone@gmail.com',890,1,124,723);
# INSERT INTO "user" VALUES(8000,'Some Guy','someone@gmail.com',858,1,450,-839);
# INSERT INTO "user" VALUES(8001,'Some Guy','someone@gmail.com',553,1,570,-471);
# INSERT INTO "user" VALUES(8002,'Some Guy','someone@gmail.com',468,1,801,737);
# INSERT INTO "user" VALUES(8003,'Some Guy','someone@gmail.com',488,1,832,35);
# INSERT INTO "user" VALUES(8004,'Some Guy','someone@gmail.com',745,1,231,971);
# INSERT INTO "user" VALUES(8005,'Some Guy','someone@gmail.com',562,1,873,471);
# INSERT INTO "user" VALUES(8006,'Some Guy','someone@gmail.com',779,1,763,-329);
# INSERT INTO "user" VALUES(8007,'Some Guy','someone@gmail.com',333,1,326,-201);
# INSERT INTO "user" VALUES(8008,'Some Guy','someone@gmail.com',370,1,883,-601);
# INSERT INTO "user" VALUES(8009,'Some Guy','someone@gmail.com',588,1,191,185);
# INSERT INTO "user" VALUES(8010,'Some Guy','someone@gmail.com',366,1,866,132);
# INSERT INTO "user" VALUES(8011,'Some Guy','someone@gmail.com',527,1,923,103);
# INSERT INTO "user" VALUES(8012,'Some Guy','someone@gmail.com',818,1,460,113);
# INSERT INTO "user" VALUES(8013,'Some Guy','someone@gmail.com',372,1,223,961);
# INSERT INTO "user" VALUES(8014,'Some Guy','someone@gmail.com',265,1,78,273);
# INSERT INTO "user" VALUES(8015,'Some Guy','someone@gmail.com',542,1,630,-172);
# INSERT INTO "user" VALUES(8016,'Some Guy','someone@gmail.com',663,1,574,-594);
# INSERT INTO "user" VALUES(8017,'Some Guy','someone@gmail.com',842,1,707,923);
# INSERT INTO "user" VALUES(8018,'Some Guy','someone@gmail.com',758,1,229,-523);
# INSERT INTO "user" VALUES(8019,'Some Guy','someone@gmail.com',505,1,284,-582);
# INSERT INTO "user" VALUES(8020,'Some Guy','someone@gmail.com',772,1,580,737);
# INSERT INTO "user" VALUES(8021,'Some Guy','someone@gmail.com',672,1,182,-66);
# INSERT INTO "user" VALUES(8022,'Some Guy','someone@gmail.com',587,1,178,364);
# INSERT INTO "user" VALUES(8023,'Some Guy','someone@gmail.com',701,1,255,-370);
# INSERT INTO "user" VALUES(8024,'Some Guy','someone@gmail.com',112,1,417,-127);
# INSERT INTO "user" VALUES(8025,'Some Guy','someone@gmail.com',484,1,644,367);
# INSERT INTO "user" VALUES(8026,'Some Guy','someone@gmail.com',731,1,720,-693);
# INSERT INTO "user" VALUES(8027,'Some Guy','someone@gmail.com',733,1,113,-684);
# INSERT INTO "user" VALUES(8028,'Some Guy','someone@gmail.com',688,1,721,423);
# INSERT INTO "user" VALUES(8029,'Some Guy','someone@gmail.com',613,1,375,-161);
# INSERT INTO "user" VALUES(8030,'Some Guy','someone@gmail.com',844,1,978,77);
# INSERT INTO "user" VALUES(8031,'Some Guy','someone@gmail.com',455,1,813,-311);
# INSERT INTO "user" VALUES(8032,'Some Guy','someone@gmail.com',280,1,551,-877);
# INSERT INTO "user" VALUES(8033,'Some Guy','someone@gmail.com',243,1,500,488);
# INSERT INTO "user" VALUES(8034,'Some Guy','someone@gmail.com',703,1,764,-148);
# INSERT INTO "user" VALUES(8035,'Some Guy','someone@gmail.com',152,1,646,-293);
# INSERT INTO "user" VALUES(8036,'Some Guy','someone@gmail.com',522,1,193,-814);
# INSERT INTO "user" VALUES(8037,'Some Guy','someone@gmail.com',827,1,273,-457);
# INSERT INTO "user" VALUES(8038,'Some Guy','someone@gmail.com',628,1,87,-601);
# INSERT INTO "user" VALUES(8039,'Some Guy','someone@gmail.com',841,1,726,788);
# INSERT INTO "user" VALUES(8040,'Some Guy','someone@gmail.com',441,1,490,-775);
# INSERT INTO "user" VALUES(8041,'Some Guy','someone@gmail.com',295,1,358,-488);
# INSERT INTO "user" VALUES(8042,'Some Guy','someone@gmail.com',917,1,855,785);
# INSERT INTO "user" VALUES(8043,'Some Guy','someone@gmail.com',749,1,901,-668);
# INSERT INTO "user" VALUES(8044,'Some Guy','someone@gmail.com',206,1,996,-481);
# INSERT INTO "user" VALUES(8045,'Some Guy','someone@gmail.com',898,1,125,867);
# INSERT INTO "user" VALUES(8046,'Some Guy','someone@gmail.com',565,1,558,-443);
# INSERT INTO "user" VALUES(8047,'Some Guy','someone@gmail.com',399,1,776,-241);
# INSERT INTO "user" VALUES(8048,'Some Guy','someone@gmail.com',805,1,376,-192);
# INSERT INTO "user" VALUES(8049,'Some Guy','someone@gmail.com',461,1,675,-785);
# INSERT INTO "user" VALUES(8050,'Some Guy','someone@gmail.com',427,1,856,801);
# INSERT INTO "user" VALUES(8051,'Some Guy','someone@gmail.com',886,1,943,-466);
# INSERT INTO "user" VALUES(8052,'Some Guy','someone@gmail.com',177,1,657,821);
# INSERT INTO "user" VALUES(8053,'Some Guy','someone@gmail.com',685,1,916,436);
# INSERT INTO "user" VALUES(8054,'Some Guy','someone@gmail.com',522,1,606,-476);
# INSERT INTO "user" VALUES(8055,'Some Guy','someone@gmail.com',636,1,807,861);
# INSERT INTO "user" VALUES(8056,'Some Guy','someone@gmail.com',421,1,121,494);
# INSERT INTO "user" VALUES(8057,'Some Guy','someone@gmail.com',338,1,908,967);
# INSERT INTO "user" VALUES(8058,'Some Guy','someone@gmail.com',577,1,344,-665);
# INSERT INTO "user" VALUES(8059,'Some Guy','someone@gmail.com',979,1,937,-271);
# INSERT INTO "user" VALUES(8060,'Some Guy','someone@gmail.com',135,1,277,489);
# INSERT INTO "user" VALUES(8061,'Some Guy','someone@gmail.com',488,1,822,-76);
# INSERT INTO "user" VALUES(8062,'Some Guy','someone@gmail.com',868,1,887,-54);
# INSERT INTO "user" VALUES(8063,'Some Guy','someone@gmail.com',662,1,387,322);
# INSERT INTO "user" VALUES(8064,'Some Guy','someone@gmail.com',881,1,80,-410);
# INSERT INTO "user" VALUES(8065,'Some Guy','someone@gmail.com',570,1,792,-322);
# INSERT INTO "user" VALUES(8066,'Some Guy','someone@gmail.com',800,1,782,560);
# INSERT INTO "user" VALUES(8067,'Some Guy','someone@gmail.com',185,1,933,68);
# INSERT INTO "user" VALUES(8068,'Some Guy','someone@gmail.com',233,1,476,937);
# INSERT INTO "user" VALUES(8069,'Some Guy','someone@gmail.com',241,1,761,521);
# INSERT INTO "user" VALUES(8070,'Some Guy','someone@gmail.com',117,1,332,-504);
# INSERT INTO "user" VALUES(8071,'Some Guy','someone@gmail.com',410,1,531,447);
# INSERT INTO "user" VALUES(8072,'Some Guy','someone@gmail.com',597,1,443,-241);
# INSERT INTO "user" VALUES(8073,'Some Guy','someone@gmail.com',545,1,560,871);
# INSERT INTO "user" VALUES(8074,'Some Guy','someone@gmail.com',453,1,405,709);
# INSERT INTO "user" VALUES(8075,'Some Guy','someone@gmail.com',957,1,523,580);
# INSERT INTO "user" VALUES(8076,'Some Guy','someone@gmail.com',464,1,268,835);
# INSERT INTO "user" VALUES(8077,'Some Guy','someone@gmail.com',320,1,583,-725);
# INSERT INTO "user" VALUES(8078,'Some Guy','someone@gmail.com',175,1,29,707);
# INSERT INTO "user" VALUES(8079,'Some Guy','someone@gmail.com',779,1,364,-518);
# INSERT INTO "user" VALUES(8080,'Some Guy','someone@gmail.com',232,1,222,-646);
# INSERT INTO "user" VALUES(8081,'Some Guy','someone@gmail.com',165,1,357,-508);
# INSERT INTO "user" VALUES(8082,'Some Guy','someone@gmail.com',909,1,708,-221);
# INSERT INTO "user" VALUES(8083,'Some Guy','someone@gmail.com',775,1,230,214);
# INSERT INTO "user" VALUES(8084,'Some Guy','someone@gmail.com',892,1,108,673);
# INSERT INTO "user" VALUES(8085,'Some Guy','someone@gmail.com',729,1,935,628);
# INSERT INTO "user" VALUES(8086,'Some Guy','someone@gmail.com',671,1,338,106);
# INSERT INTO "user" VALUES(8087,'Some Guy','someone@gmail.com',179,1,526,-499);
# INSERT INTO "user" VALUES(8088,'Some Guy','someone@gmail.com',317,1,65,435);
# INSERT INTO "user" VALUES(8089,'Some Guy','someone@gmail.com',882,1,575,-853);
# INSERT INTO "user" VALUES(8090,'Some Guy','someone@gmail.com',477,1,93,-48);
# INSERT INTO "user" VALUES(8091,'Some Guy','someone@gmail.com',495,1,949,-430);
# INSERT INTO "user" VALUES(8092,'Some Guy','someone@gmail.com',324,1,758,812);
# INSERT INTO "user" VALUES(8093,'Some Guy','someone@gmail.com',404,1,685,-539);
# INSERT INTO "user" VALUES(8094,'Some Guy','someone@gmail.com',531,1,548,-816);
# INSERT INTO "user" VALUES(8095,'Some Guy','someone@gmail.com',613,1,688,325);
# INSERT INTO "user" VALUES(8096,'Some Guy','someone@gmail.com',277,1,248,83);
# INSERT INTO "user" VALUES(8097,'Some Guy','someone@gmail.com',794,1,921,409);
# INSERT INTO "user" VALUES(8098,'Some Guy','someone@gmail.com',216,1,240,-545);
# INSERT INTO "user" VALUES(8099,'Some Guy','someone@gmail.com',440,1,743,-575);
# INSERT INTO "user" VALUES(8100,'Some Guy','someone@gmail.com',767,1,435,-273);
# DELETE FROM "sqlite_sequence";
# INSERT INTO "sqlite_sequence" VALUES('user',8100);
# INSERT INTO "sqlite_sequence" VALUES('games',3000);
# INSERT INTO "sqlite_sequence" VALUES('car',10);
# COMMIT;

# %% [markdown]
# ### Rebuilding DB by querries from sql_damp

# %%
with sq.connect("generated.db") as con:
    cur = con.cursor()
    for sql in con.iterdump():
        print(sql)

    with open("sql_damp.sql", "r") as f:
        sql = f.read()
        cur.executescript(sql)

# %% [markdown]
# ### Creating DB in memory

# %%
data = [("car", "машина"), ("house", "дом"), ("tree", "дерево"), ("color", "цвет")]

con = sq.connect(':memory:')
with con:
    cur = con.cursor()
    cur.execute("""CREATE TABLE IF NOT EXISTS dict(
        eng TEXT, rus TEXT    
    )""")

    cur.executemany("INSERT INTO dict VALUES(?,?)", data)

    cur.execute("SELECT rus FROM dict WHERE eng LIKE 'c%'")
    print(cur.fetchall())
