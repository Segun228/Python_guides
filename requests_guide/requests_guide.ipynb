# %% [markdown]
# # Requests

# %%
import requests 

response = requests.get('https://github.com/Segun228') # отправить get-запрос

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '\n\n<!DOCTYPE html>\n<html\n  lang="en"\n  \n  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"\n  data-a11y-animated-images="system" data-a11y-link-underlines="true"\n  \n  >\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-c59dc71e3a4c.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light_high_contrast-4bf0cb726930.css" /><link crossorigin="anonym
# ...

# %%
response.content # для получения файла
# Out:
# b'\n\n<!DOCTYPE html>\n<html\n  lang="en"\n  \n  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"\n  data-a11y-animated-images="system" data-a11y-link-underlines="true"\n  \n  >\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-c59dc71e3a4c.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light_high_contrast-4bf0cb726930.css" /><link crossorigin="anony
# ...

# %%
response = requests.get('https://jsonplaceholder.typicode.com/todos/')
json_answer = response.json


import pprint
pprint.pprint(json_answer)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
response.headers # заголовки ответа
# Out:
# {'Date': 'Sat, 28 Jun 2025 17:33:53 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '4005', 'Connection': 'keep-alive', 'Access-Control-Allow-Credentials': 'true', 'Cache-Control': 'max-age=43200', 'Content-Encoding': 'gzip', 'Etag': 'W/"5ef7-4Ad6/n39KWY9q6Ykm/ULNQ2F5IM"', 'Expires': '-1', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Pragma': 'no-cache', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=X%2FkOCbdg%2FNDRA0BWJCMTYKD1byozi4SgsEHjPRcUyFI%3D\\u0026sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d\\u0026ts=1749250119"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=X%2FkOCbdg%2FNDRA0BWJCMTYKD1byozi4SgsEHjPRcUyFI%3D&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&ts=1749250119"', 'Server': 'cloudflare', 'Vary': 'Origin, Accept-Encoding', 'Via': '2.0 heroku-router', 'X-Content-Type-Options': 'nosniff', '
# ...

# %%
response.request.headers # заголовки запроса

# %% [markdown]
# ## Headers

# %%
jwt = "i3uh498rf9384f3hf983hfh3h98f9h38f938hf"
token_object = {
    "token": f"Bearer {jwt}"
}
response = requests.get('https://jsonplaceholder.typicode.com/todos/', headers= token_object)

# %% [markdown]
# ## GET-parameters

# %%
params = {'q': 'python'}
response = requests.get('https://api.github.com/search/repositories', params= params)
response.text
# Out:
# '{"total_count":5060754,"incomplete_results":false,"items":[{"id":63476337,"node_id":"MDEwOlJlcG9zaXRvcnk2MzQ3NjMzNw==","name":"Python","full_name":"TheAlgorithms/Python","private":false,"owner":{"login":"TheAlgorithms","id":20487725,"node_id":"MDEyOk9yZ2FuaXphdGlvbjIwNDg3NzI1","avatar_url":"https://avatars.githubusercontent.com/u/20487725?v=4","gravatar_id":"","url":"https://api.github.com/users/TheAlgorithms","html_url":"https://github.com/TheAlgorithms","followers_url":"https://api.github.com/users/TheAlgorithms/followers","following_url":"https://api.github.com/users/TheAlgorithms/following{/other_user}","gists_url":"https://api.github.com/users/TheAlgorithms/gists{/gist_id}","starred_url":"https://api.github.com/users/TheAlgorithms/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/TheAlgorithms/subscriptions","organizations_url":"https://api.github.com/users/TheAlgorithms/orgs","repos_url":"https://api.github.com/users/TheAlgorithms/repos","events_url":"h
# ...

# %% [markdown]
# ## Cookies

# %%
cookies = {"session_token": "oijoiej320r9u230ur909jwqfj3f0923jf09"}
response = requests.get('https://httpbin.org/cookies', cookies=cookies)
response.text
# Out:
# '{\n  "cookies": {\n    "session_token": "oijoiej320r9u230ur909jwqfj3f0923jf09"\n  }\n}\n'

# %% [markdown]
# ## Sessions

# %%
with requests.Session() as session:
    session.get('https://httpbin.org/cookies/set/sessioncookie/123456789')
    response = session.get("https://httpbin.org/cookies")
    print(response.text)
# Out:
# {
#   "cookies": {
#     "sessioncookie": "123456789"
#   }
# }

# %% [markdown]
# ## Post

# %%
data = {"key": "value"}
response = requests.post("https://httpbin.org/post", data=data)
response.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.4", \n    "X-Amzn-Trace-Id": "Root=1-68602c80-2e1cd2b43e278dbf637420ea"\n  }, \n  "json": null, \n  "origin": "84.17.46.67", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
data = {"key": "value"}
response = requests.post("https://httpbin.org/post", json=data)
response.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.4", \n    "X-Amzn-Trace-Id": "Root=1-68602c80-2e1cd2b43e278dbf637420ea"\n  }, \n  "json": null, \n  "origin": "84.17.46.67", \n  "url": "https://httpbin.org/post"\n}\n'

# %% [markdown]
# ## Downloading data

# %%
img_url = "https://i.pinimg.com/736x/e5/b9/81/e5b98110fcd62d6ebe0e636262170175.jpg"
response = requests.get(img_url)
with open('image.jpg', "wb") as file:
    file.write(response.content)
