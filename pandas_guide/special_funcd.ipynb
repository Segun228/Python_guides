# %%
import pandas as pd
import numpy as np
import matplotlib as mplb
import seaborn as sns
import scypy as sp
glos = {
    "alcohol":["vodka", "whiskey", "absent"],
    "strength":[40, 38, 70]
}
alc1 = pd.DataFrame(glos)
# Out:
# True

# %%
alc2 = alc1.copy(deep=True)
alc1.equals(alc2)
# Out:
# True

# %%
alc2.sample(2)
# Out:
#    alcohol  strength
# 1  whiskey        38
# 2   absent        70
