# %% [markdown]
# # Python CSV Guide

# %% [markdown]
# ## Opening CSV

# %%
import csv


name_1 = "Anna"
name_2 = "Robert"

with open("data.csv", "w") as file:
    writer = csv.writer(file)
    writer.writerow(
        [name_1, name_2]
    )

# %% [markdown]
# ## Adding column names

# %%
with open("users.csv", "w") as file:
    writer = csv.writer(file)
    writer.writerow(
        ["username", "email", "password"]
    )

# %% [markdown]
# ## Generating data

# %%
import random
import string

def generate_username():
    return "user_" + ''.join(random.choices(string.ascii_lowercase + string.digits, k=6))

def generate_email(username="email"):
    domains = ["example.com", "test.org", "mail.com"]
    return f"{username}@{random.choice(domains)}"

def generate_password(length=10):
    chars = string.ascii_letters + string.digits + "!@#$%^&*()"
    return ''.join(random.choices(chars, k=length))


num_users = 100
user_data = [[generate_username(), generate_email(), generate_password()] for _ in range(100)]

# %% [markdown]
# ## Adding data

# %%
with open("users.csv", "a") as file:
    writer = csv.writer(file)
    for el in user_data:
        writer.writerow(
            el
        )

# %%
with open("users.csv", "a", encoding="UTF-8") as file:
    writer = csv.writer(file, delimiter=";")
    writer.writerows(user_data)

# %% [markdown]
# ## Reading data

# %%
result = []
with open("users.csv", newline="", encoding="utf-8") as file:
    reader = csv.reader(file)
    for row in reader:
        result.append(row)
# Out:
# [['user_3i8a0r', 'email@example.com', '8vNP60UN46'],
#  ['user_m1wy4f', 'email@example.com', 'JB*a5n5YVM'],
#  ['user_h7exmt', 'email@mail.com', 'cO6wsGxgTj'],
#  ['user_l3inum', 'email@example.com', 'saEXu*(k&h'],
#  ['user_5gzgj8', 'email@mail.com', 'W7mdhJSiEo'],
#  ['user_akkdzo', 'email@mail.com', 'Y7kRLXDT^9'],
#  ['user_ookkxr', 'email@mail.com', 'jyy%*3qNTu'],
#  ['user_mjlbmn', 'email@mail.com', '(H0bd!bK^u'],
#  ['user_kw63vw', 'email@example.com', 'd#6L7%a3uM'],
#  ['user_ktew8c', 'email@mail.com', 'YlnXPcD$t6'],
#  ['user_2mde6r', 'email@example.com', 'r2zCfWvtNT'],
#  ['user_uiqgpi', 'email@test.org', '0s@8Hl!21u'],
#  ['user_2l9kyb', 'email@mail.com', '8lreyQoaJL'],
#  ['user_cs9h62', 'email@example.com', 'NrPPzkr*vI'],
#  ['user_l2dh8i', 'email@example.com', 'rX!Ha1J@bT'],
#  ['user_jvg4w0', 'email@test.org', 'BHey!lEEtV'],
#  ['user_5h23ct', 'email@test.org', 'lFTIWNRy8v'],
#  ['user_9e0frl', 'email@example.com', 'GKM65N)lqn'],
#  ['user_nm9twz', 'email@test.org', 'rbO3)TePnO'],
#  ['user_xfolv5', 'email@mail.com', 'D2O5@P^$7Q'],
#  ['user_w6hw2i', 'email@test.org', 'XIX5w1OcZT'],
#  ['user_jgcwqr', 'email@test.org', '&44!*fCPoV'],
#  ['user_poz3kw', 'email@mail.com', 'NIa3^@s^ld'],
#  ['user_u5n9yy', 'email@test.org', 'j!^inGqOov'],
#  ['user_7sk2w9', 'email@test.org', 'x(Jtt0oWJK'],
#  ['user_02yum3', 'email@test.org', 'CZX2fJsGlM'],
#  ['user_85udvt', 'email@example.com', 'L8HfAYnk)v'],
#  ['user_pu1it5', 'email@example.com', 'EWc17O3eWi'],
#  ['user_8dzu0r', 'email@test.org', 'bJwoqx4Bb$'],
#  ['user_syc02v', 'email@mail.com', 'NHMRI7ZoIR'],
#  ['user_9lg6jm', 'email@example.com', 'Qh&(VU65UJ'],
#  ['user_zz9y9p', 'email@mail.com', 'akvIDmM@6q'],
#  ['user_s0zss6', 'email@mail.com', 'Sk@*adcZ&$'],
#  ['user_ntu0jf', 'email@example.com', '3t$bdsRQ6A'],
#  ['user_9wt49y', 'email@example.com', 'R11JP%Ek2d'],
#  ['user_6wlavm', 'email@test.org', 'JSOZsNDLm%'],
#  ['user_m03m17', 'email@mail.com', 'B17(J*%7bO'],
#  ['user_6bbazt', 'email@test.org', 'PrC4PBG4Wx'],
#  ['user_34zn44', 'email@example.com', '2psQx!O#3D'],
#  ['user_0caerk', 'email@example.com', 'CnsqX&3T8W'],
#  ['user_lxqchb', 'email@example.com', 'GVpVTZg8w8'],
#  ['user_zm2tgd', 'email@mail.com', '2XBuChcYKi'],
#  ['user_pbqhzw', 'email@example.com', 'CAYpHT0PUU'],
#  ['user_j8ua2z', 'email@example.com', 'cBlJ15lurF'],
#  ['user_bbxj5t', 'email@example.com', 'sWlel$mfwL'],
#  ['user_1wc9t6', 'email@example.com', 'Pdg&!JTFqD'],
#  ['user_pvduut', 'email@test.org', 'Nu!Hj03862'],
#  ['user_70guj1', 'email@example.com', 'sZg%5b8Bmc'],
#  ['user_aggo71', 'email@example.com', '!MLXjo^U!#'],
#  ['user_zeadwc', 'email@mail.com', 'FKmg6JVJLr'],
#  ['user_fgi2c0', 'email@example.com', 'PQK9y7SWQi'],
#  ['user_e1cs97', 'email@test.org', 'yLBijvQGi5'],
#  ['user_eud8ha', 'email@test.org', 's@gApyYog7'],
#  ['user_ewznln', 'email@example.com', '!1F%x%O0Cg'],
#  ['user_xfaqps', 'email@mail.com', 'P5UR%aPh9L'],
#  ['user_gho826', 'email@test.org', 'mNk#xie8pD'],
#  ['user_2an86g', 'email@mail.com', 'u&7iLjqCp7'],
#  ['user_u0coik', 'email@example.com', '^M1#@MN2zg'],
#  ['user_5j5gkl', 'email@mail.com', '9WWZx&f27N'],
#  ['user_tc8nuu', 'email@example.com', 'rodk6b7)32'],
#  ['user_d5seww', 'email@mail.com', 'BrHFF^DDvd'],
#  ['user_vzn5f0', 'email@test.org', 'nwn5EzmT!y'],
#  ['user_512v0n', 'email@mail.com', '3%Uc5#w0k&'],
#  ['user_qzltvc', 'email@mail.com', '3UolTt$fBu'],
#  ['user_elvlmb', 'email@test.org', 'b@ojniz&TA'],
#  ['user_p2rkwr', 'email@example.com', 'FjcsOC5^jC'],
#  ['user_11ub69', 'email@example.com', 'esJTd%2qf1'],
#  ['user_ynbxcn', 'email@mail.com', 'O3sB8j5fXl'],
#  ['user_t5oqy0', 'email@example.com', 'H^FhiZQmB6'],
#  ['user_uxrw4q', 'email@test.org', 'fF^gh3xYNR'],
#  ['user_x3lotr', 'email@test.org', '6CmaH@pTC9'],
#  ['user_c8ruyf', 'email@mail.com', '6RH^mCe@Ix'],
#  ['user_7j31rw', 'email@mail.com', '^a!o4pH7#8'],
#  ['user_go1dzw', 'email@test.org', 'KBV@46jJ)O'],
#  ['user_5e2trg', 'email@example.com', 'FgL2TVWQu1'],
#  ['user_hzr9xv', 'email@mail.com', 'dDGk8LRccI'],
#  ['user_9h8de3', 'email@example.com', 'iu0f@M7!0e'],
#  ['user_1tlp49', 'email@test.org', 'i&lf&pmUW9'],
#  ['user_jc2jd3', 'email@test.org', 'tINUW5^s(p'],
#  ['user_dqaoal', 'email@example.com', 'e^UxpX#7h)'],
#  ['user_3v808u', 'email@mail.com', 'cp%F&#Fwkc'],
#  ['user_71gc0q', 'email@mail.com', 'kOLybmRjSO'],
#  ['user_stubny', 'email@test.org', '1ZLG#XCo*t'],
#  ['user_1r0kn2', 'email@example.com', 'u^qzMo^CP2'],
#  ['user_of9r37', 'email@test.org', '9*dq1CPVw*'],
#  ['user_8jea8i', 'email@mail.com', 'rk7I9vBO$f'],
#  ['user_az9kio', 'email@example.com', 'ihMoOr3Gzl'],
#  ['user_23slsm', 'email@example.com', 'NpvEG1dyd%'],
#  ['user_ucbkk9', 'email@test.org', '(64WvM%JTO'],
#  ['user_r3a9ek', 'email@test.org', 'B&L2@0qASu'],
#  ['user_ejbzc5', 'email@example.com', 'lYYaw4djIq'],
#  ['user_t7irkd', 'email@test.org', '!9OMTcEt4t'],
#  ['user_1y3kor', 'email@test.org', ')6FtJFJVxb'],
#  ['user_029w46', 'email@example.com', 'udLpTqz5ZA'],
#  ['user_u6mc1q', 'email@mail.com', 'hV%QA6zIkA'],
#  ['user_0gpsij', 'email@mail.com', 'SQGsEYlftI'],
#  ['user_f2jqrc', 'email@mail.com', '09Uix9gP2U'],
#  ['user_606eq3', 'email@example.com', 'My&#ia7fI1'],
#  ['user_eo9tsm', 'email@example.com', 'G#Km&$zJ07'],
#  ['user_4a2wor', 'email@mail.com', 'vdvvm7%z%Y']]

# %%
result = []
with open("users.csv", newline="", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    for row in reader:
        result.append(row)
result
# Out:
# [{'username': 'user_b55n38',
#   'email': 'email@test.org',
#   'password': 'YNsN&8xAtV'},
#  {'username': 'user_qdxbrk',
#   'email': 'email@mail.com',
#   'password': 'S0FUkA7iH8'},
#  {'username': 'user_vkcorx',
#   'email': 'email@mail.com',
#   'password': 'yzgw*JXFvF'},
#  {'username': 'user_8pc67d',
#   'email': 'email@test.org',
#   'password': 'I&B*lsYpd7'},
#  {'username': 'user_bjc9v1',
#   'email': 'email@mail.com',
#   'password': '@$#(r4AMAJ'},
#  {'username': 'user_hcbt9d',
#   'email': 'email@mail.com',
#   'password': 'xN7@LOEfcP'},
#  {'username': 'user_9n71h9',
#   'email': 'email@test.org',
#   'password': 'Bkd270bkfI'},
#  {'username': 'user_3bypo4',
#   'email': 'email@example.com',
#   'password': '5j2Cq5RCbt'},
#  {'username': 'user_goc9t5',
#   'email': 'email@example.com',
#   'password': '586qQe5DeO'},
#  {'username': 'user_ldgrzk',
#   'email': 'email@example.com',
#   'password': 'sghE(##yln'},
#  {'username': 'user_jqulch',
#   'email': 'email@test.org',
#   'password': 'HqjcZ(Cioz'},
#  {'username': 'user_gbg7t4',
#   'email': 'email@example.com',
#   'password': '^9#XgC4j8N'},
#  {'username': 'user_zbetj7',
#   'email': 'email@test.org',
#   'password': 'CxrK17kMXs'},
#  {'username': 'user_9fvuvi',
#   'email': 'email@test.org',
#   'password': 'ULX%I$7^8g'},
#  {'username': 'user_vvr0s3',
#   'email': 'email@example.com',
#   'password': 'G$vj$q3Skz'},
#  {'username': 'user_cygv39',
#   'email': 'email@test.org',
#   'password': 'xCg01C#wfM'},
#  {'username': 'user_xyz2qx',
#   'email': 'email@mail.com',
#   'password': 'WLHN5p!LlO'},
#  {'username': 'user_6fiylq',
#   'email': 'email@test.org',
#   'password': '5jX(epR3hg'},
#  {'username': 'user_2yh2di',
#   'email': 'email@example.com',
#   'password': 'z))UlBOrbC'},
#  {'username': 'user_ih42lh',
#   'email': 'email@example.com',
#   'password': 'Iy(3rweDPZ'},
#  {'username': 'user_x89igd',
#   'email': 'email@example.com',
#   'password': 'MgfpkSFuoW'},
#  {'username': 'user_3mu0un',
#   'email': 'email@mail.com',
#   'password': 'ST0%&Z8#ap'},
#  {'username': 'user_8zpyl5',
#   'email': 'email@test.org',
#   'password': ')J1)B2r8Gi'},
#  {'username': 'user_lh613x',
#   'email': 'email@test.org',
#   'password': 'QBdxqC6&ll'},
#  {'username': 'user_f8d54i',
#   'email': 'email@example.com',
#   'password': 'j(&D6WWVXK'},
#  {'username': 'user_gu554d',
#   'email': 'email@test.org',
#   'password': '6#4blDQAK^'},
#  {'username': 'user_7ud0jo',
#   'email': 'email@test.org',
#   'password': 'OvtZdQronx'},
#  {'username': 'user_4z6ytg',
#   'email': 'email@test.org',
#   'password': '0Re6kjK*4M'},
#  {'username': 'user_jl3qrw',
#   'email': 'email@mail.com',
#   'password': 'v(8^q%13g4'},
#  {'username': 'user_1q3pbt',
#   'email': 'email@example.com',
#   'password': 'uUn1jnpL*%'},
#  {'username': 'user_xob09q',
#   'email': 'email@mail.com',
#   'password': 'Sr31$wyyiU'},
#  {'username': 'user_tno0ww',
#   'email': 'email@example.com',
#   'password': 'e)PVm3Toyz'},
#  {'username': 'user_c171ls',
#   'email': 'email@mail.com',
#   'password': '1C6%vlJgpE'},
#  {'username': 'user_7g7tf5',
#   'email': 'email@test.org',
#   'password': 'RXauJDiL25'},
#  {'username': 'user_ny1zj1',
#   'email': 'email@mail.com',
#   'password': 'o6tB*VWkos'},
#  {'username': 'user_hujjxr',
#   'email': 'email@test.org',
#   'password': 'Q2gAw(tiTA'},
#  {'username': 'user_golwd1',
#   'email': 'email@mail.com',
#   'password': '@E)Z@5Sntc'},
#  {'username': 'user_j696k6',
#   'email': 'email@example.com',
#   'password': 'E4Z6Q(vpg9'},
#  {'username': 'user_kugn54',
#   'email': 'email@test.org',
#   'password': 'LOS0s7Nc6m'},
#  {'username': 'user_h6bo5k',
#   'email': 'email@example.com',
#   'password': 'Xo&oLwP7ks'},
#  {'username': 'user_5ee3xg',
#   'email': 'email@test.org',
#   'password': 'kZjMgN09I#'},
#  {'username': 'user_u05y05',
#   'email': 'email@mail.com',
#   'password': '$6Zv#MUwS#'},
#  {'username': 'user_rwlc6p',
#   'email': 'email@example.com',
#   'password': 'CcIAChkdjm'},
#  {'username': 'user_lfqfnn',
#   'email': 'email@test.org',
#   'password': 'QWFgAlJG8s'},
#  {'username': 'user_t5tgyf',
#   'email': 'email@test.org',
#   'password': 'w%$u8cJC^T'},
#  {'username': 'user_3oryn5',
#   'email': 'email@mail.com',
#   'password': '&37FEcvj9G'},
#  {'username': 'user_m4zf79',
#   'email': 'email@mail.com',
#   'password': 'RdpvjKfGCZ'},
#  {'username': 'user_na0ubx',
#   'email': 'email@test.org',
#   'password': 'G2Zs7QeZkb'},
#  {'username': 'user_zx5lyw',
#   'email': 'email@example.com',
#   'password': '4KWs!!&XdR'},
#  {'username': 'user_rc84fs',
#   'email': 'email@mail.com',
#   'password': '0aW2q)Fu5q'},
#  {'username': 'user_6cgktp',
#   'email': 'email@test.org',
#   'password': 'c21GK6yuET'},
#  {'username': 'user_ugoajx',
#   'email': 'email@example.com',
#   'password': 'Rkt1%sFFYp'},
#  {'username': 'user_wcl6aa',
#   'email': 'email@mail.com',
#   'password': '$L@^HKI)To'},
#  {'username': 'user_se19qn',
#   'email': 'email@example.com',
#   'password': 'mHg4ZgMPCC'},
#  {'username': 'user_hz1ra3',
#   'email': 'email@example.com',
#   'password': '8i(2rBg)mv'},
#  {'username': 'user_hotf01',
#   'email': 'email@example.com',
#   'password': '@PZgihW)NL'},
#  {'username': 'user_qxc3s7',
#   'email': 'email@example.com',
#   'password': 'vUcT7yR$o&'},
#  {'username': 'user_7n41w9',
#   'email': 'email@mail.com',
#   'password': 'RfzAeB8LNr'},
#  {'username': 'user_gqv201',
#   'email': 'email@mail.com',
#   'password': '5N@7PoTIzM'},
#  {'username': 'user_s319qv',
#   'email': 'email@mail.com',
#   'password': 'AgRBwB)Qyb'},
#  {'username': 'user_s94j5s',
#   'email': 'email@test.org',
#   'password': 'EHy0e#wR)t'},
#  {'username': 'user_1hgryz',
#   'email': 'email@test.org',
#   'password': 'guPtC*5BVR'},
#  {'username': 'user_uuckle',
#   'email': 'email@example.com',
#   'password': '3bzchR4h)z'},
#  {'username': 'user_1ws52e',
#   'email': 'email@test.org',
#   'password': 'uUcuO7l#uk'},
#  {'username': 'user_zotqbm',
#   'email': 'email@mail.com',
#   'password': 'wgypz*Ixkg'},
#  {'username': 'user_yef7vn',
#   'email': 'email@mail.com',
#   'password': 'BIy4668J4)'},
#  {'username': 'user_5w2arf',
#   'email': 'email@mail.com',
#   'password': 'J2UFuGgVWC'},
#  {'username': 'user_xsmejb',
#   'email': 'email@example.com',
#   'password': 'QbCsl5buIH'},
#  {'username': 'user_ewjuhj',
#   'email': 'email@example.com',
#   'password': 'XCOBs3&dsF'},
#  {'username': 'user_qjixap',
#   'email': 'email@test.org',
#   'password': 'M)T$zQcE9)'},
#  {'username': 'user_uncart',
#   'email': 'email@mail.com',
#   'password': '*7Etv21krT'},
#  {'username': 'user_3dn4ii',
#   'email': 'email@test.org',
#   'password': 'oGH!SI3@x)'},
#  {'username': 'user_ctuv7j',
#   'email': 'email@test.org',
#   'password': '!GnKYy)U9f'},
#  {'username': 'user_nyyoom',
#   'email': 'email@example.com',
#   'password': 'I22gGTjp))'},
#  {'username': 'user_5hwmnt',
#   'email': 'email@mail.com',
#   'password': 'KK@l&IEHqc'},
#  {'username': 'user_j4yttx',
#   'email': 'email@example.com',
#   'password': '2ekXTOKX*P'},
#  {'username': 'user_l2gh2b',
#   'email': 'email@example.com',
#   'password': 'WvBwqjyQw2'},
#  {'username': 'user_i8ndwk',
#   'email': 'email@example.com',
#   'password': '(kg*L3RFLt'},
#  {'username': 'user_8ugadn',
#   'email': 'email@example.com',
#   'password': '^JFZt(Sb$C'},
#  {'username': 'user_4t8vn6',
#   'email': 'email@mail.com',
#   'password': 'la&)FBV7c^'},
#  {'username': 'user_0rl58y',
#   'email': 'email@mail.com',
#   'password': 'hjBXuAk59H'},
#  {'username': 'user_mstihz',
#   'email': 'email@test.org',
#   'password': '7!KA540lbU'},
#  {'username': 'user_sekade',
#   'email': 'email@test.org',
#   'password': 'Ny#m$z9Yg*'},
#  {'username': 'user_6gxi8q',
#   'email': 'email@test.org',
#   'password': 'Ezx0(*hbG('},
#  {'username': 'user_b41fya',
#   'email': 'email@example.com',
#   'password': 'hq9t^TLr6r'},
#  {'username': 'user_m0zf0c',
#   'email': 'email@test.org',
#   'password': 'o88JWh&Cqo'},
#  {'username': 'user_h9zgyc',
#   'email': 'email@example.com',
#   'password': 'w@9p)dN*M&'},
#  {'username': 'user_cdtsfj',
#   'email': 'email@example.com',
#   'password': '7diIJhOD5r'},
#  {'username': 'user_1sd06x',
#   'email': 'email@example.com',
#   'password': 'Uw5rom!3sR'},
#  {'username': 'user_00u56g',
#   'email': 'email@test.org',
#   'password': '3(iMX@SFf4'},
#  {'username': 'user_inn31m',
#   'email': 'email@mail.com',
#   'password': 'CFB6MdL7BC'},
#  {'username': 'user_f7x0sc',
#   'email': 'email@mail.com',
#   'password': 'QlP&VcSF)r'},
#  {'username': 'user_wyjmp2',
#   'email': 'email@mail.com',
#   'password': '1XPNoPkpsl'},
#  {'username': 'user_0e44ku',
#   'email': 'email@test.org',
#   'password': 'ua70E68S)i'},
#  {'username': 'user_fxjatm',
#   'email': 'email@test.org',
#   'password': 'aMd939MSQ6'},
#  {'username': 'user_obdrum',
#   'email': 'email@test.org',
#   'password': 'CIXu%87UHu'},
#  {'username': 'user_1qm721',
#   'email': 'email@mail.com',
#   'password': '!3toqpaal9'},
#  {'username': 'user_pgcoff',
#   'email': 'email@mail.com',
#   'password': '$ucYn#r5kP'},
#  {'username': 'user_qqcfmo',
#   'email': 'email@test.org',
#   'password': 'Qi93jwvyLZ'},
#  {'username': 'user_5x4a7j',
#   'email': 'email@test.org',
#   'password': '9V3%(23VS&'}]
